# %%
import os 
from multiprocessing import Pool, cpu_count
from radiomics import featureextractor

# %% [markdown]
# # GTV extraction

# %%
def parallelize_rad_extraction(nifti_folder: str, patient: str, extractor: featureextractor.RadiomicsFeatureExtractor, output_file_path: str): 
    series = os.listdir(nifti_folder + patient)
    for s in series: 
        img_path = nifti_folder + patient + "/" + s + '/Aniso_N4_filtered_image.nii.gz'
        mask_path = nifti_folder + patient + "/" + s + '/mask_GTV.nii.gz'
        result = extractor.execute(img_path, mask_path)
        print(result)
        continue 
    # TODO: write results in the csv file

# %%
print("Feature extractation.")

params = 'Params_MRIdian.yaml'
output_file_path = 'extractedFeature.csv'
# Initialize feature extractor using the settings file
extractor = featureextractor.RadiomicsFeatureExtractor(params)
headers = None

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
# patients_list = ['Mont1'] # TODO: remove after testing 
print("Number of cores: ", cpu_count())
for p in patients_list: 
    parallelize_rad_extraction(nifti_folder, p, extractor, output_file_path)
# with Pool(cpu_count()) as pool:
#     pool.starmap(parallelize_rad_extraction, [(nifti_folder, p) for p in patients_list])
# Out:
# Feature extractation.
# Number of cores:  16
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
