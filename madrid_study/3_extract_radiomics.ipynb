# %%
import os 
from multiprocessing import Pool, cpu_count
from radiomics import featureextractor
import pandas as pd

# %% [markdown]
# First we extract the 'raw' csv, with all the information from Pyradiomics

# %% [markdown]
# # Raw csv extraction

# %%
def rad_extraction(nifti_folder: str, patients_list: list, fraction: str, img_name: str, mask_type: str, params: str): 
    assert mask_type in ['GTV', 'PTV'], "mask_type should be either GTV or PTV"
    extractor = featureextractor.RadiomicsFeatureExtractor(params)
    
    k = 0 
    for patient in patients_list:
        
        img_path = nifti_folder + patient + "/" + fraction + '/' + img_name + '.nii.gz'
        mask_path = nifti_folder + patient + "/" + fraction + '/mask_' + mask_type + '.nii.gz'
        try: 
            result = extractor.execute(img_path, mask_path)
        except Exception as e:
            print(f"Error processing {patient}: {e}")
            
        feature_names = list(result.keys())
        if k == 0:
            output_df = pd.DataFrame(index=patients_list, columns=feature_names)

        for feature_name in feature_names:
            output_df.loc[patient, feature_name] = str(result[feature_name])

        k += 1
    return output_df

# %% [markdown]
# ## GTV extraction
# ### Simu

# %%
params_file_name = 'Params_MRIdian.yaml'
fraction = 'SIMU'
mask_type = 'GTV'
img_name = 'Aniso_N4_filtered_image' # TODO: run!!!! 

output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
output_df.head()
# Out:
#        diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# Mont10                           v3.1.0                     1.24.4
# Mont39                           v3.1.0                     1.24.4
# Mont38                           v3.1.0                     1.24.4
# Mont1                            v3.1.0                     1.24.4
# Mont32                           v3.1.0                     1.24.4
#
#        diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# Mont10                          2.4.0                          1.4.1
# Mont39                          2.4.0                          1.4.1
# Mont38                          2.4.0                          1.4.1
# Mont1                           2.4.0                          1.4.1
# Mont32                          2.4.0                          1.4.1
#
#        diagnostics_Versions_Python  \
# Mont10                      3.8.20
# Mont39                      3.8.20
# Mont38                      3.8.20
# Mont1                       3.8.20
# Mont32                      3.8.20
#
#                        diagnostics_Configuration_Settings  \
# Mont10  {'minimumROIDimensions': 2, 'minimumROISize': ...
# Mont39  {'minimumROIDimensions': 2, 'minimumROISize': ...
# Mont38  {'minimumROIDimensions': 2, 'minimumROISize': ...
# Mont1   {'minimumROIDimensions': 2, 'minimumROISize': ...
# Mont32  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#        diagnostics_Configuration_EnabledImageTypes  \
# Mont10                            {'Original': {}}
# Mont39                            {'Original': {}}
# Mont38                            {'Original': {}}
# Mont1                             {'Original': {}}
# Mont32                            {'Original': {}}
#
#                  diagnostics_Image-original_Hash  \
# Mont10  a68499f96011b0441ac17a3d7452dc01910a9f9b
# Mont39  2b091a54974a8ce5a2022f950afa8f777b77ada2
# Mont38  cd011890af2c6c4a3f88b2ca66915f9ab8ab0dc3
# Mont1   33e1c0f81cfcce860e589e3cad3aef6559d1c543
# Mont32  aaceea91b3836fd2c3eab2a428a129f9a875bc47
#
#        diagnostics_Image-original_Dimensionality  \
# Mont10                                        3D
# Mont39                                        3D
# Mont38                                        3D
# Mont1                                         3D
# Mont32                                        3D
#
#                   diagnostics_Image-original_Spacing  ...  \
# Mont10                 (1.5, 1.5, 2.999999761581421)  ...
# Mont39  (1.4939024448394775, 1.5, 2.999999761581421)  ...
# Mont38                 (1.5, 1.504424810409546, 3.0)  ...
# Mont1                  (1.5, 1.5, 3.000000238418579)  ...
# Mont32                 (1.5, 1.5, 2.999999761581421)  ...
#
#        original_gldm_LargeDependenceLowGrayLevelEmphasis  \
# Mont10                               0.06966021645171634
# Mont39                                 0.792970557705377
# Mont38                                0.2727802595811297
# Mont1                                 0.1516184582590862
# Mont32                               0.25462377575188305
#
#        original_gldm_LowGrayLevelEmphasis  \
# Mont10               0.006722093669896986
# Mont39               0.033740777191289185
# Mont38               0.010127877004974722
# Mont1                0.008742977612637275
# Mont32               0.011753475676679868
#
#        original_gldm_SmallDependenceEmphasis  \
# Mont10                    0.3325642792437132
# Mont39                   0.18248112424312837
# Mont38                   0.14137903553519915
# Mont1                    0.23498896062785893
# Mont32                   0.18471676563385464
#
#        original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# Mont10                                  134.7149118700065
# Mont39                                 21.017576661333354
# Mont38                                  25.48536407447622
# Mont1                                    84.8070710646567
# Mont32                                  41.83177436330133
#
#        original_gldm_SmallDependenceLowGrayLevelEmphasis  \
# Mont10                              0.002875010163611217
# Mont39                              0.007464216971025351
# Mont38                              0.001765213355819211
# Mont1                              0.0019274158774937285
# Mont32                             0.0022647630257989597
#
#        original_ngtdm_Busyness original_ngtdm_Coarseness  \
# Mont10      0.1699573374975758      0.009337291671831465
# Mont39      0.3035984722848974       0.01721982819771472
# Mont38      0.4201325713635331      0.007388763788579951
# Mont1       1.0112158199881913     0.0010779177438026784
# Mont32      3.7769683854291474     0.0006318266377635422
#
#        original_ngtdm_Complexity original_ngtdm_Contrast  \
# Mont10        1287.9187538004132      0.1525177905721789
# Mont39        245.15415540298164     0.06604536469120648
# Mont38         301.5510926224392     0.06570864281418566
# Mont1         3133.7395075952204     0.08063726175165306
# Mont32         823.7748649470784     0.08714530316677722
#
#        original_ngtdm_Strength
# Mont10        4.64362907334703
# Mont39       3.376976425857462
# Mont38      1.5291746184619035
# Mont1        2.376555923864709
# Mont32      0.2730129530980905
#
# [5 rows x 154 columns]

# %% [markdown]
# ### F1

# %%
fraction = 'F1'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
output_df.shape
# Out:
# (37, 154)

# %% [markdown]
# ### F2

# %%
fraction = 'F2'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F3

# %%
fraction = 'F3'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F4

# %%
fraction = 'F4'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F5

# %%
fraction = 'F5'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ## PTV extraction

# %% [markdown]
# ### Simu

# %%
params_file_name = 'Params_MRIdian.yaml'
fraction = 'SIMU'
mask_type = 'PTV'
img_name = 'Aniso_N4_filtered_image' 

output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F1

# %%
fraction = 'F1'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F2

# %%
fraction = 'F2'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F3

# %%
fraction = 'F3'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F4

# %%
fraction = 'F4'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F5

# %%
fraction = 'F5'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# # Filter raw csv
# ## Repeatability analysis ICM

# %%
repeat_file = "/home/tachennf/Documents/delta-rad/data/ICM_0.35T/filtered_features_gtv.xlsx"
repeatable_features_gtv_df = pd.read_excel(repeat_file, index_col=0)
repeatable_features_gtv_df.head()
# Out:
#                                 original_shape_Elongation  \
# ID
# Patient38_IRM_simu_mridian_gtv                   0.431793
# Patient38_mridian_ttt_2_gtv                      0.442144
# Patient38_mridian_ttt_4_gtv                      0.442374
# Patient38_mridian_ttt_5_gtv                      0.442374
# Patient10_IRM_simu_GIE_gtv                       0.672158
#
#                                 original_shape_Flatness  \
# ID
# Patient38_IRM_simu_mridian_gtv                 0.370555
# Patient38_mridian_ttt_2_gtv                    0.371772
# Patient38_mridian_ttt_4_gtv                    0.371341
# Patient38_mridian_ttt_5_gtv                    0.371341
# Patient10_IRM_simu_GIE_gtv                     0.549602
#
#                                 original_shape_LeastAxisLength  \
# ID
# Patient38_IRM_simu_mridian_gtv                       24.678556
# Patient38_mridian_ttt_2_gtv                          24.636047
# Patient38_mridian_ttt_4_gtv                          24.625888
# Patient38_mridian_ttt_5_gtv                          24.625888
# Patient10_IRM_simu_GIE_gtv                           25.401274
#
#                                 original_shape_MajorAxisLength  \
# ID
# Patient38_IRM_simu_mridian_gtv                       66.598953
# Patient38_mridian_ttt_2_gtv                          66.266497
# Patient38_mridian_ttt_4_gtv                          66.316118
# Patient38_mridian_ttt_5_gtv                          66.316118
# Patient10_IRM_simu_GIE_gtv                           46.217551
#
#                                 original_shape_Maximum2DDiameterColumn  \
# ID
# Patient38_IRM_simu_mridian_gtv                               53.068955
# Patient38_mridian_ttt_2_gtv                                  52.185463
# Patient38_mridian_ttt_4_gtv                                  53.068955
# Patient38_mridian_ttt_5_gtv                                  53.068955
# Patient10_IRM_simu_GIE_gtv                                   46.704549
#
#                                 original_shape_Maximum2DDiameterRow  \
# ID
# Patient38_IRM_simu_mridian_gtv                            57.813322
# Patient38_mridian_ttt_2_gtv                               57.813322
# Patient38_mridian_ttt_4_gtv                               57.813322
# Patient38_mridian_ttt_5_gtv                               57.813322
# Patient10_IRM_simu_GIE_gtv                                54.477126
#
#                                 original_shape_Maximum2DDiameterSlice  \
# ID
# Patient38_IRM_simu_mridian_gtv                              47.606047
# Patient38_mridian_ttt_2_gtv                                 47.606047
# Patient38_mridian_ttt_4_gtv                                 47.606047
# Patient38_mridian_ttt_5_gtv                                 47.606047
# Patient10_IRM_simu_GIE_gtv                                  38.744658
#
#                                 original_shape_Maximum3DDiameter  \
# ID
# Patient38_IRM_simu_mridian_gtv                         68.904864
# Patient38_mridian_ttt_2_gtv                            69.633631
# Patient38_mridian_ttt_4_gtv                            68.904864
# Patient38_mridian_ttt_5_gtv                            68.904864
# Patient10_IRM_simu_GIE_gtv                             54.865907
#
#                                 original_shape_MeshVolume  \
# ID
# Patient38_IRM_simu_mridian_gtv                24300.18231
# Patient38_mridian_ttt_2_gtv                   24369.47426
# Patient38_mridian_ttt_4_gtv                   24464.75070
# Patient38_mridian_ttt_5_gtv                   24464.75070
# Patient10_IRM_simu_GIE_gtv                    18814.74989
#
#                                 original_shape_MinorAxisLength  ...  \
# ID                                                              ...
# Patient38_IRM_simu_mridian_gtv                       28.756943  ...
# Patient38_mridian_ttt_2_gtv                          29.299306  ...
# Patient38_mridian_ttt_4_gtv                          29.336497  ...
# Patient38_mridian_ttt_5_gtv                          29.336497  ...
# Patient10_IRM_simu_GIE_gtv                           31.065518  ...
#
#                                 original_ngtdm_Coarseness  \
# ID
# Patient38_IRM_simu_mridian_gtv                   0.001856
# Patient38_mridian_ttt_2_gtv                      0.001997
# Patient38_mridian_ttt_4_gtv                      0.002107
# Patient38_mridian_ttt_5_gtv                      0.002032
# Patient10_IRM_simu_GIE_gtv                       0.003128
#
#                                 original_ngtdm_Contrast  Patient Rxmic  \
# ID
# Patient38_IRM_simu_mridian_gtv                 0.175404     Patient 38
# Patient38_mridian_ttt_2_gtv                    0.128942     Patient 38
# Patient38_mridian_ttt_4_gtv                    0.153118     Patient 38
# Patient38_mridian_ttt_5_gtv                    0.169598     Patient 38
# Patient10_IRM_simu_GIE_gtv                     0.828998     Patient 10
#
#                                           Fraction  Volume  Récidive Locale  \
# ID
# Patient38_IRM_simu_mridian_gtv  Simulation mridian     GTV                0
# Patient38_mridian_ttt_2_gtv                      2     GTV                0
# Patient38_mridian_ttt_4_gtv                      4     GTV                0
# Patient38_mridian_ttt_5_gtv                      5     GTV                0
# Patient10_IRM_simu_GIE_gtv          Simulation GIE     GTV                0
#
#                                 Récidive Méta  Décès  Récidive  Évènement
# ID
# Patient38_IRM_simu_mridian_gtv              0      1         0          1
# Patient38_mridian_ttt_2_gtv                 0      1         0          1
# Patient38_mridian_ttt_4_gtv                 0      1         0          1
# Patient38_mridian_ttt_5_gtv                 0      1         0          1
# Patient10_IRM_simu_GIE_gtv                  1      1         1          1
#
# [5 rows x 89 columns]

# %%
repeatable_features = repeatable_features_gtv_df.columns[:-8]
print('Number of repeatable features:', len(repeatable_features))
# Out:
# Number of repeatable features: 81

# %% [markdown]
# ## Reproducibility analysis ICM

# %%
icc_file = "/home/tachennf/Documents/delta-rad/data/ICM_0.35T/results_icc.csv"
icc_df = pd.read_csv(icc_file)
icc_df.head()
# Out:
#                                   Feature    ICC
# 0              original_shape_SurfaceArea  0.964
# 1     original_firstorder_RootMeanSquared  0.316
# 2       original_shape_SurfaceVolumeRatio  0.985
# 3  original_shape_Maximum2DDiameterColumn  0.985
# 4                      original_glcm_Imc2  0.826

# %%
threshold = 0.75
reproductible_features = icc_df[icc_df['ICC'] >= threshold]

# %%
filtered_features = list(set(repeatable_features) & set(reproductible_features['Feature']))

# %% [markdown]
# ## Filtered
# ### SIMU GTV

# %%
simu_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/SIMU_GTV_extracted_features.csv', index_col=0)
filtered_simu_df = simu_df[filtered_features]
filtered_simu_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/simu_gtv.csv', index=True)
filtered_simu_df.head(5)
# Out:
#         original_shape_Sphericity  original_glrlm_LongRunEmphasis  \
# Mont10                   0.681037                        1.240127
# Mont39                   0.774345                        1.661803
# Mont38                   0.752608                        1.687161
# Mont1                    0.689326                        1.371010
# Mont32                   0.631497                        1.457574
#
#         original_glrlm_RunLengthNonUniformityNormalized  \
# Mont10                                         0.867236
# Mont39                                         0.748215
# Mont38                                         0.733044
# Mont1                                          0.822783
# Mont32                                         0.792842
#
#         original_gldm_DependenceNonUniformity  \
# Mont10                             282.849930
# Mont39                              56.367041
# Mont38                             135.528213
# Mont1                             1577.043466
# Mont32                            2553.441751
#
#         original_gldm_GrayLevelNonUniformity  original_glcm_SumEntropy  \
# Mont10                             55.507714                  5.684689
# Mont39                             65.247191                  4.169496
# Mont38                            124.670846                  4.389333
# Mont1                             546.024051                  5.475522
# Mont32                           1054.022527                  5.202837
#
#         original_shape_Maximum2DDiameterSlice  original_glcm_Correlation  \
# Mont10                              30.450913                   0.749476
# Mont39                              18.584859                   0.533214
# Mont38                              26.282960                   0.597222
# Mont1                               49.332752                   0.803610
# Mont32                              78.781460                   0.712656
#
#         original_shape_Maximum2DDiameterColumn  original_ngtdm_Coarseness  \
# Mont10                               38.641659                   0.009337
# Mont39                               22.170397                   0.017220
# Mont38                               28.466726                   0.007389
# Mont1                                58.316653                   0.001078
# Mont32                               63.402600                   0.000632
#
#         ...  original_shape_LeastAxisLength  original_firstorder_Entropy  \
# Mont10  ...                       17.135989                     4.822023
# Mont39  ...                       10.703229                     3.493069
# Mont38  ...                       17.172183                     3.669701
# Mont1   ...                       35.181256                     4.604248
# Mont32  ...                       40.949026                     4.343913
#
#         original_glcm_Idm  original_glszm_ZoneEntropy  \
# Mont10           0.229505                    6.656038
# Mont39           0.420449                    5.566407
# Mont38           0.405943                    6.152571
# Mont1            0.277431                    7.105892
# Mont32           0.311482                    7.041696
#
#         original_glrlm_RunVariance  original_glrlm_RunEntropy  \
# Mont10                    0.081036                   5.189219
# Mont39                    0.251577                   4.231849
# Mont38                    0.258689                   4.415851
# Mont1                     0.133726                   5.135233
# Mont32                    0.165527                   4.944509
#
#         original_glrlm_RunPercentage  original_shape_Maximum3DDiameter  \
# Mont10                      0.929280                         39.187858
# Mont39                      0.846442                         23.844844
# Mont38                      0.840728                         30.668267
# Mont1                       0.900133                         63.234757
# Mont32                      0.881327                         81.320502
#
#         original_glrlm_RunLengthNonUniformity  original_shape_Flatness
# Mont10                            1149.866000                 0.539026
# Mont39                             339.649095                 0.503594
# Mont38                             789.439152                 0.720539
# Mont1                             7676.606275                 0.642585
# Mont32                           13049.199700                 0.654236
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F1

# %%
f1_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F1_GTV_extracted_features.csv', index_col=0)
filtered_f1_df = f1_df[filtered_features]
filtered_f1_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/f1_gtv.csv', index=True)
filtered_f1_df.head(5)
# Out:
#         original_shape_Sphericity  original_glrlm_LongRunEmphasis  \
# Mont10                   0.676434                        1.366571
# Mont39                   0.754164                        1.266766
# Mont38                   0.737445                        1.959555
# Mont1                    0.691686                        1.498829
# Mont32                   0.643833                        1.441950
#
#         original_glrlm_RunLengthNonUniformityNormalized  \
# Mont10                                         0.824211
# Mont39                                         0.865918
# Mont38                                         0.670898
# Mont1                                          0.782794
# Mont32                                         0.798924
#
#         original_gldm_DependenceNonUniformity  \
# Mont10                             227.710900
# Mont39                             100.419355
# Mont38                              68.720183
# Mont1                             1493.445121
# Mont32                            2446.589085
#
#         original_gldm_GrayLevelNonUniformity  original_glcm_SumEntropy  \
# Mont10                             95.866622                  4.960418
# Mont39                             18.407258                  5.769836
# Mont38                            123.149083                  3.979632
# Mont1                             948.719036                  4.649499
# Mont32                            965.085489                  5.284571
#
#         original_shape_Maximum2DDiameterSlice  original_glcm_Correlation  \
# Mont10                              33.004984                   0.612915
# Mont39                              18.584859                   0.841954
# Mont38                              23.338048                   0.730832
# Mont1                               47.717537                   0.566427
# Mont32                              80.943903                   0.732849
#
#         original_shape_Maximum2DDiameterColumn  original_ngtdm_Coarseness  \
# Mont10                               39.693094                   0.006769
# Mont39                               21.929407                   0.035786
# Mont38                               26.981301                   0.010735
# Mont1                                59.086095                   0.000765
# Mont32                               62.473883                   0.000682
#
#         ...  original_shape_LeastAxisLength  original_firstorder_Entropy  \
# Mont10  ...                       16.939371                     4.266198
# Mont39  ...                        9.662655                     4.957776
# Mont38  ...                       13.548696                     3.318930
# Mont1   ...                       37.022867                     3.900546
# Mont32  ...                       40.172991                     4.411955
#
#         original_glcm_Idm  original_glszm_ZoneEntropy  \
# Mont10           0.296037                    6.406298
# Mont39           0.247617                    6.436004
# Mont38           0.498227                    5.644389
# Mont1            0.331288                    6.659970
# Mont32           0.307003                    6.973166
#
#         original_glrlm_RunVariance  original_glrlm_RunEntropy  \
# Mont10                    0.132069                   4.778233
# Mont39                    0.094640                   5.284771
# Mont38                    0.363488                   4.298019
# Mont1                     0.182952                   4.546411
# Mont32                    0.161227                   5.001305
#
#         original_glrlm_RunPercentage  original_shape_Maximum3DDiameter  \
# Mont10                      0.900630                         39.993172
# Mont39                      0.925868                         23.166653
# Mont38                      0.794725                         28.837644
# Mont1                       0.874261                         63.066467
# Mont32                      0.884831                         81.874042
#
#         original_glrlm_RunLengthNonUniformity  original_shape_Flatness
# Mont10                            1097.228374                 0.551064
# Mont39                             398.692953                 0.475863
# Mont38                             466.681449                 0.562810
# Mont1                             7882.479576                 0.662501
# Mont32                           12502.033858                 0.648594
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F2

# %%
f2_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F2_GTV_extracted_features.csv', index_col=0)
filtered_f2_df = f2_df[filtered_features]
filtered_f2_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/f2_gtv.csv', index=True)
filtered_f2_df.head(5)
# Out:
#         original_shape_Sphericity  original_glrlm_LongRunEmphasis  \
# Mont10                   0.707340                        1.260043
# Mont39                   0.735870                        1.226722
# Mont38                   0.774195                        1.644071
# Mont1                    0.709575                        1.687860
# Mont32                   0.651377                        1.524802
#
#         original_glrlm_RunLengthNonUniformityNormalized  \
# Mont10                                         0.865070
# Mont39                                         0.882091
# Mont38                                         0.738673
# Mont1                                          0.728806
# Mont32                                         0.773657
#
#         original_gldm_DependenceNonUniformity  \
# Mont10                             288.051771
# Mont39                              88.657568
# Mont38                              97.853007
# Mont1                             1131.889952
# Mont32                            2341.528504
#
#         original_gldm_GrayLevelNonUniformity  original_glcm_SumEntropy  \
# Mont10                             74.539510                  5.259862
# Mont39                             22.255583                  5.091404
# Mont38                             84.534521                  4.499194
# Mont1                            1106.526785                  4.343008
# Mont32                           1055.304544                  5.228857
#
#         original_shape_Maximum2DDiameterSlice  original_glcm_Correlation  \
# Mont10                              33.004984                   0.580974
# Mont39                              16.622804                   0.524065
# Mont38                              20.423841                   0.718811
# Mont1                               47.044635                   0.580109
# Mont32                              80.268191                   0.773830
#
#         original_shape_Maximum2DDiameterColumn  original_ngtdm_Coarseness  \
# Mont10                               39.390730                   0.006195
# Mont39                               21.252600                   0.022517
# Mont38                               24.450000                   0.012692
# Mont1                                58.362195                   0.000851
# Mont32                               62.473883                   0.000692
#
#         ...  original_shape_LeastAxisLength  original_firstorder_Entropy  \
# Mont10  ...                       16.942794                     4.553842
# Mont39  ...                       11.212420                     4.351479
# Mont38  ...                       14.907314                     3.695888
# Mont1   ...                       36.409011                     3.564960
# Mont32  ...                       40.613126                     4.345792
#
#         original_glcm_Idm  original_glszm_ZoneEntropy  \
# Mont10           0.232548                    6.462259
# Mont39           0.228743                    5.897988
# Mont38           0.411581                    5.914717
# Mont1            0.398250                    6.430057
# Mont32           0.336727                    7.015145
#
#         original_glrlm_RunVariance  original_glrlm_RunEntropy  \
# Mont10                    0.092058                   4.948113
# Mont39                    0.081361                   4.655861
# Mont38                    0.233181                   4.410934
# Mont1                     0.254731                   4.355652
# Mont32                    0.193831                   4.999337
#
#         original_glrlm_RunPercentage  original_shape_Maximum3DDiameter  \
# Mont10                      0.925854                         39.525399
# Mont39                      0.935866                         22.230236
# Mont38                      0.846753                         26.333456
# Mont1                       0.838425                         62.410058
# Mont32                      0.868121                         84.209656
#
#         original_glrlm_RunLengthNonUniformity  original_shape_Flatness
# Mont10                            1176.508662                 0.559049
# Mont39                             333.186471                 0.585944
# Mont38                             564.397601                 0.656721
# Mont1                             6533.616679                 0.675162
# Mont32                           12553.060148                 0.639640
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F3

# %%
f3_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F3_GTV_extracted_features.csv', index_col=0)
filtered_f3_df = f3_df[filtered_features]   
filtered_f3_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/f3_gtv.csv', index=True)
filtered_f3_df.head(5)
# Out:
#         original_shape_Sphericity  original_glrlm_LongRunEmphasis  \
# Mont10                   0.696081                        1.268186
# Mont39                   0.785173                        1.247085
# Mont38                   0.768245                        1.977910
# Mont1                    0.713131                        1.448869
# Mont32                   0.637624                        1.434831
#
#         original_glrlm_RunLengthNonUniformityNormalized  \
# Mont10                                         0.859475
# Mont39                                         0.870572
# Mont38                                         0.665785
# Mont1                                          0.794542
# Mont32                                         0.801524
#
#         original_gldm_DependenceNonUniformity  \
# Mont10                             318.878499
# Mont39                             111.702899
# Mont38                              63.180645
# Mont1                             1370.770690
# Mont32                            2964.780474
#
#         original_gldm_GrayLevelNonUniformity  original_glcm_SumEntropy  \
# Mont10                             85.980345                  5.239984
# Mont39                             27.786232                  5.248832
# Mont38                            126.223226                  3.839393
# Mont1                             580.084812                  5.130144
# Mont32                           1014.137084                  5.420063
#
#         original_shape_Maximum2DDiameterSlice  original_glcm_Correlation  \
# Mont10                              36.629694                   0.598448
# Mont39                              18.584859                   0.630953
# Mont38                              24.231692                   0.672811
# Mont1                               45.901217                   0.712587
# Mont32                              81.124234                   0.772222
#
#         original_shape_Maximum2DDiameterColumn  original_ngtdm_Coarseness  \
# Mont10                               39.693094                   0.005896
# Mont39                               21.252600                   0.018968
# Mont38                               24.880870                   0.010922
# Mont1                                57.026710                   0.001093
# Mont32                               64.048838                   0.000628
#
#         ...  original_shape_LeastAxisLength  original_firstorder_Entropy  \
# Mont10  ...                       17.897686                     4.517293
# Mont39  ...                       11.727629                     4.515172
# Mont38  ...                       14.042114                     3.080811
# Mont1   ...                       34.782342                     4.270143
# Mont32  ...                       42.230031                     4.536483
#
#         original_glcm_Idm  original_glszm_ZoneEntropy  \
# Mont10           0.242410                    6.625440
# Mont39           0.242834                    6.284128
# Mont38           0.508333                    5.434153
# Mont1            0.311252                    6.958285
# Mont32           0.302946                    7.124642
#
#         original_glrlm_RunVariance  original_glrlm_RunEntropy  \
# Mont10                    0.093503                   4.926966
# Mont39                    0.085960                   4.863974
# Mont38                    0.366080                   4.061327
# Mont1                     0.160450                   4.859012
# Mont32                    0.158433                   5.112643
#
#         original_glrlm_RunPercentage  original_shape_Maximum3DDiameter  \
# Mont10                      0.923214                         40.521157
# Mont39                      0.929627                         23.109238
# Mont38                      0.792953                         27.372355
# Mont1                       0.883365                         61.961444
# Mont32                      0.886368                         83.464914
#
#         original_glrlm_RunLengthNonUniformity  original_shape_Flatness
# Mont10                            1333.175887                 0.569298
# Mont39                             447.522391                 0.585858
# Mont38                             411.557602                 0.596775
# Mont1                             6860.439607                 0.637644
# Mont32                           14893.446536                 0.655197
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F4

# %%
f4_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F4_GTV_extracted_features.csv', index_col=0)
filtered_f4_df = f4_df[filtered_features]
filtered_f4_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/f4_gtv.csv', index=True)
filtered_f4_df.head(5)
# Out:
#         original_shape_Sphericity  original_glrlm_LongRunEmphasis  \
# Mont10                   0.703437                        1.600607
# Mont39                   0.769709                        1.183192
# Mont38                   0.779620                        1.801518
# Mont1                    0.692931                        1.541799
# Mont32                   0.622666                        1.489186
#
#         original_glrlm_RunLengthNonUniformityNormalized  \
# Mont10                                         0.741491
# Mont39                                         0.894356
# Mont38                                         0.707597
# Mont1                                          0.770094
# Mont32                                         0.782775
#
#         original_gldm_DependenceNonUniformity  \
# Mont10                             156.514695
# Mont39                             174.131054
# Mont38                              61.229318
# Mont1                             1190.233647
# Mont32                            2516.324634
#
#         original_gldm_GrayLevelNonUniformity  original_glcm_SumEntropy  \
# Mont10                            126.766390                  4.431575
# Mont39                             28.829060                  5.542182
# Mont38                             98.573295                  4.005392
# Mont1                             747.735214                  4.746066
# Mont32                           1063.924697                  5.230818
#
#         original_shape_Maximum2DDiameterSlice  original_glcm_Correlation  \
# Mont10                              31.480529                   0.618228
# Mont39                              19.078661                   0.613196
# Mont38                              26.282960                   0.516978
# Mont1                               47.939738                   0.638401
# Mont32                              81.500000                   0.746545
#
#         original_shape_Maximum2DDiameterColumn  original_ngtdm_Coarseness  \
# Mont10                               37.912833                   0.007557
# Mont39                               24.066662                   0.013984
# Mont38                               23.733158                   0.010390
# Mont1                                57.629203                   0.001012
# Mont32                               66.491214                   0.000665
#
#         ...  original_shape_LeastAxisLength  original_firstorder_Entropy  \
# Mont10  ...                       16.335832                     3.623408
# Mont39  ...                       12.183614                     4.792842
# Mont38  ...                       11.307890                     3.309615
# Mont1   ...                       34.631655                     3.932964
# Mont32  ...                       41.557741                     4.353876
#
#         original_glcm_Idm  original_glszm_ZoneEntropy  \
# Mont10           0.402823                    6.180073
# Mont39           0.198425                    6.415944
# Mont38           0.457155                    5.651537
# Mont1            0.348147                    6.645762
# Mont32           0.325630                    7.079818
#
#         original_glrlm_RunVariance  original_glrlm_RunEntropy  \
# Mont10                    0.211956                   4.335299
# Mont39                    0.061224                   5.073095
# Mont38                    0.304276                   4.183516
# Mont1                     0.200435                   4.600207
# Mont32                    0.178008                   4.979509
#
#         original_glrlm_RunPercentage  original_shape_Maximum3DDiameter  \
# Mont10                      0.850733                         38.226888
# Mont39                      0.944664                         25.409185
# Mont38                      0.820587                         27.757900
# Mont1                       0.866000                         61.918549
# Mont32                      0.874754                         83.209864
#
#         original_glrlm_RunLengthNonUniformity  original_shape_Flatness
# Mont10                             839.145284                 0.537940
# Mont39                             593.527116                 0.530051
# Mont38                             401.343371                 0.469898
# Mont1                             6397.790453                 0.636723
# Mont32                           13087.473285                 0.664686
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F5

# %%
f5_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F5_GTV_extracted_features.csv', index_col=0)
filtered_f5_df = f5_df[filtered_features]
filtered_f5_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/f5_gtv.csv', index=True) 
filtered_f5_df.head(5)
# Out:
#         original_shape_Sphericity  original_glrlm_LongRunEmphasis  \
# Mont10                   0.689727                        1.385631
# Mont39                   0.782041                        1.212120
# Mont38                   0.752497                        2.105158
# Mont1                    0.701623                        1.691690
# Mont32                   0.640953                        1.351174
#
#         original_glrlm_RunLengthNonUniformityNormalized  \
# Mont10                                         0.814441
# Mont39                                         0.880777
# Mont38                                         0.644825
# Mont1                                          0.731953
# Mont32                                         0.828388
#
#         original_gldm_DependenceNonUniformity  \
# Mont10                             189.332248
# Mont39                             152.708571
# Mont38                              56.983957
# Mont1                             1148.392684
# Mont32                            3051.322268
#
#         original_gldm_GrayLevelNonUniformity  original_glcm_SumEntropy  \
# Mont10                             86.728013                  4.812427
# Mont39                             36.274286                  5.231041
# Mont38                             90.663102                  4.345576
# Mont1                             930.531860                  4.654728
# Mont32                            785.882518                  5.601014
#
#         original_shape_Maximum2DDiameterSlice  original_glcm_Correlation  \
# Mont10                              30.927076                   0.622876
# Mont39                              19.078661                   0.517001
# Mont38                              26.282960                   0.915249
# Mont1                               50.556283                   0.683100
# Mont32                              80.268191                   0.792630
#
#         original_shape_Maximum2DDiameterColumn  original_ngtdm_Coarseness  \
# Mont10                               37.912833                   0.008317
# Mont39                               22.170397                   0.013112
# Mont38                               26.981301                   0.016515
# Mont1                                60.661409                   0.000973
# Mont32                               63.402600                   0.000663
#
#         ...  original_shape_LeastAxisLength  original_firstorder_Entropy  \
# Mont10  ...                       15.769588                     4.072973
# Mont39  ...                       13.216196                     4.472781
# Mont38  ...                       12.438752                     3.583452
# Mont1   ...                       35.311028                     3.845724
# Mont32  ...                       40.329935                     4.712799
#
#         original_glcm_Idm  original_glszm_ZoneEntropy  \
# Mont10           0.317888                    6.362329
# Mont39           0.215604                    6.122315
# Mont38           0.531190                    5.695592
# Mont1            0.393456                    6.621979
# Mont32           0.266644                    7.266024
#
#         original_glrlm_RunVariance  original_glrlm_RunEntropy  \
# Mont10                    0.135732                   4.599904
# Mont39                    0.070814                   4.796780
# Mont38                    0.414775                   4.603611
# Mont1                     0.261411                   4.628658
# Mont32                    0.124697                   5.213823
#
#         original_glrlm_RunPercentage  original_shape_Maximum3DDiameter  \
# Mont10                      0.895828                         38.226888
# Mont39                      0.937253                         23.677118
# Mont38                      0.776429                         31.522700
# Mont1                       0.839404                         62.728533
# Mont32                      0.904169                         82.488308
#
#         original_glrlm_RunLengthNonUniformity  original_shape_Flatness
# Mont10                             897.461307                 0.513664
# Mont39                             578.710673                 0.657247
# Mont38                             377.412627                 0.460048
# Mont1                             6722.042876                 0.639970
# Mont32                           13916.711690                 0.645964
#
# [5 rows x 49 columns]

# %% [markdown]
# # Delta-radiomics

# %% [markdown]
# ## F1/F2

# %%
madrid_path = '/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/'

f1_df = pd.read_csv(madrid_path + 'f1_gtv.csv', index_col=0) # load first table 
f2_df = pd.read_csv(madrid_path + 'f2_gtv.csv', index_col=0) # load second table
f1_f2_df = pd.DataFrame(index=f1_df.index, columns=f1_df.columns) # create delta rad table with same columns and index as first table
for col in f1_df.columns:
    f1_f2_df[col] = (f2_df[col] - f1_df[col]) / f1_df[col] # calculate the difference and assign it to the delta rad table
f1_f2_df.to_csv(madrid_path + 'f1_f2_gtv.csv', index=True) # save the delta rad table

# %% [markdown]
# ## F1/F3

# %%
f3_df = pd.read_csv(madrid_path + 'f3_gtv.csv', index_col=0) # load third table
f1_f3_df = pd.DataFrame(index=f1_df.index, columns=f1_df.columns) # create delta rad table with same columns and index as first table
for col in f1_df.columns:
    f1_f3_df[col] = (f3_df[col] - f1_df[col]) / f1_df[col] # calculate the difference and assign it to the delta rad table
f1_f3_df.to_csv(madrid_path + 'f1_f3_gtv.csv', index=True) # save the delta rad table

# %% [markdown]
# ## F1/F4

# %%
f4_df = pd.read_csv(madrid_path + 'f4_gtv.csv', index_col=0) # load fourth table
f1_f4_df = pd.DataFrame(index=f1_df.index, columns=f1_df.columns) # create delta rad table with same columns and index as first table
for col in f1_df.columns:
    f1_f4_df[col] = (f4_df[col] - f1_df[col]) / f1_df[col] # calculate the difference and assign it to the delta rad table
f1_f4_df.to_csv(madrid_path + 'f1_f4_gtv.csv', index=True) # save the delta rad table

# %% [markdown]
# ## F1/F5

# %%
f5_df = pd.read_csv(madrid_path + 'f5_gtv.csv', index_col=0) # load fifth table
f1_f5_df = pd.DataFrame(index=f1_df.index, columns=f1_df.columns) # create delta rad table with same columns and index as first table
for col in f1_df.columns:
    f1_f5_df[col] = (f5_df[col] - f1_df[col]) / f1_df[col] # calculate the difference and assign it to the delta rad table
f1_f5_df.to_csv(madrid_path + 'f1_f5_gtv.csv', index=True) # save the delta rad table

# %% [markdown]
# ## F2/F3

# %%
f2_f3_df = pd.DataFrame(index=f2_df.index, columns=f2_df.columns) # create delta rad table with same columns and index as first table
for col in f2_df.columns:
    f2_f3_df[col] = (f3_df[col] - f2_df[col]) / f2_df[col] # calculate the difference and assign it to the delta rad table
f2_f3_df.to_csv(madrid_path + 'f2_f3_gtv.csv', index=True) # save the delta rad table

# %% [markdown]
# ## SIMU/F1

# %%
simu_df = pd.read_csv(madrid_path + 'simu_gtv.csv', index_col=0) # load first table
simu_f1_df = pd.DataFrame(index=f1_df.index, columns=f1_df.columns) # create delta rad table with same columns and index as first table
for col in f1_df.columns:
    simu_f1_df[col] = (f1_df[col] - simu_df[col]) / simu_df[col] # calculate the difference and assign it to the delta rad table
simu_f1_df.to_csv(madrid_path + 'simu_f1_gtv.csv', index=True) # save the delta rad table

# %% [markdown]
# ## SIMU/F3

# %%
simu_f3_df = pd.DataFrame(index=f3_df.index, columns=f3_df.columns) # create delta rad table with same columns and index as first table
for col in f3_df.columns:
    simu_f3_df[col] = (f3_df[col] - simu_df[col]) / simu_df[col] # calculate the difference and assign it to the delta rad table
simu_f3_df.to_csv(madrid_path + 'simu_f3_gtv.csv', index=True) # save the delta rad table

# %% [markdown]
# ## SIMU/F5

# %%
simu_f5_df = pd.DataFrame(index=f5_df.index, columns=f5_df.columns) # create delta rad table with same columns and index as first table
for col in f5_df.columns:
    simu_f5_df[col] = (f5_df[col] - simu_df[col]) / simu_df[col] # calculate the difference and assign it to the delta rad table
simu_f5_df.to_csv(madrid_path + 'simu_f5_gtv.csv', index=True) # save the delta rad table
