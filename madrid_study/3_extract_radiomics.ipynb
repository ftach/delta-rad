# %%
import os 
from multiprocessing import Pool, cpu_count
from radiomics import featureextractor
import pandas as pd

# %% [markdown]
# First we extract the 'raw' csv, with all the information from Pyradiomics

# %% [markdown]
# # Raw csv extraction

# %%
def rad_extraction(nifti_folder: str, patients_list: list, fraction: str, img_name: str, mask_type: str, params: str): 
    assert mask_type in ['GTV', 'PTV'], "mask_type should be either GTV or PTV"
    extractor = featureextractor.RadiomicsFeatureExtractor(params)
    
    k = 0 
    for patient in patients_list:
        
        img_path = nifti_folder + patient + "/" + fraction + '/' + img_name + '.nii.gz'
        mask_path = nifti_folder + patient + "/" + fraction + '/mask_' + mask_type + '.nii.gz'
        try: 
            result = extractor.execute(img_path, mask_path)
        except Exception as e:
            print(f"Error processing {patient}: {e}")
            
        feature_names = list(result.keys())
        if k == 0:
            output_df = pd.DataFrame(index=patients_list, columns=feature_names)

        for feature_name in feature_names:
            output_df.loc[patient, feature_name] = str(result[feature_name])

        k += 1
    return output_df

# %% [markdown]
# ## GTV extraction
# ### Simu

# %%
params_file_name = 'Params_MRIdian.yaml'
fraction = 'SIMU'
mask_type = 'GTV'
img_name = 'Aniso_N4_filtered_image' # TODO: run!!!! 

output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
output_df.head()

# %% [markdown]
# ### F1

# %%
fraction = 'F1'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
output_df.shape
# Out:
# (37, 154)

# %% [markdown]
# ### F2

# %%
fraction = 'F2'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F3

# %%
fraction = 'F3'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F4

# %%
fraction = 'F4'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F5

# %%
fraction = 'F5'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ## PTV extraction

# %% [markdown]
# ### Simu

# %%
params_file_name = 'Params_MRIdian.yaml'
fraction = 'SIMU'
mask_type = 'PTV'
img_name = 'Aniso_N4_filtered_image' 

output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F1

# %%
fraction = 'F1'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F2

# %%
fraction = 'F2'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F3

# %%
fraction = 'F3'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F4

# %%
fraction = 'F4'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# ### F5

# %%
fraction = 'F5'
output_file_path = '/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/' + fraction + '_' + mask_type + '_extracted_features.csv'

nifti_folder = "/home/tachennf/Documents/delta-rad/data/Madrid/nifti_data/"
patients_list = os.listdir(nifti_folder)
output_df = rad_extraction(nifti_folder, patients_list, fraction, img_name, mask_type, params_file_name)
output_df.to_csv(output_file_path, index=True)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# # Filter raw csv
# ## Repeatability analysis ICM

# %%
repeat_file = "/home/tachennf/Documents/delta-rad/data/ICM_0.35T/filtered_features_gtv.xlsx"
repeatable_features_gtv_df = pd.read_excel(repeat_file, index_col=0)
repeatable_features_gtv_df.head()
# Out:
#                                 original_shape_Elongation  \
# ID
# Patient38_IRM_simu_mridian_gtv                   0.431793
# Patient38_mridian_ttt_2_gtv                      0.442144
# Patient38_mridian_ttt_4_gtv                      0.442374
# Patient38_mridian_ttt_5_gtv                      0.442374
# Patient10_IRM_simu_GIE_gtv                       0.672158
#
#                                 original_shape_Flatness  \
# ID
# Patient38_IRM_simu_mridian_gtv                 0.370555
# Patient38_mridian_ttt_2_gtv                    0.371772
# Patient38_mridian_ttt_4_gtv                    0.371341
# Patient38_mridian_ttt_5_gtv                    0.371341
# Patient10_IRM_simu_GIE_gtv                     0.549602
#
#                                 original_shape_LeastAxisLength  \
# ID
# Patient38_IRM_simu_mridian_gtv                       24.678556
# Patient38_mridian_ttt_2_gtv                          24.636047
# Patient38_mridian_ttt_4_gtv                          24.625888
# Patient38_mridian_ttt_5_gtv                          24.625888
# Patient10_IRM_simu_GIE_gtv                           25.401274
#
#                                 original_shape_MajorAxisLength  \
# ID
# Patient38_IRM_simu_mridian_gtv                       66.598953
# Patient38_mridian_ttt_2_gtv                          66.266497
# Patient38_mridian_ttt_4_gtv                          66.316118
# Patient38_mridian_ttt_5_gtv                          66.316118
# Patient10_IRM_simu_GIE_gtv                           46.217551
#
#                                 original_shape_Maximum2DDiameterColumn  \
# ID
# Patient38_IRM_simu_mridian_gtv                               53.068955
# Patient38_mridian_ttt_2_gtv                                  52.185463
# Patient38_mridian_ttt_4_gtv                                  53.068955
# Patient38_mridian_ttt_5_gtv                                  53.068955
# Patient10_IRM_simu_GIE_gtv                                   46.704549
#
#                                 original_shape_Maximum2DDiameterRow  \
# ID
# Patient38_IRM_simu_mridian_gtv                            57.813322
# Patient38_mridian_ttt_2_gtv                               57.813322
# Patient38_mridian_ttt_4_gtv                               57.813322
# Patient38_mridian_ttt_5_gtv                               57.813322
# Patient10_IRM_simu_GIE_gtv                                54.477126
#
#                                 original_shape_Maximum2DDiameterSlice  \
# ID
# Patient38_IRM_simu_mridian_gtv                              47.606047
# Patient38_mridian_ttt_2_gtv                                 47.606047
# Patient38_mridian_ttt_4_gtv                                 47.606047
# Patient38_mridian_ttt_5_gtv                                 47.606047
# Patient10_IRM_simu_GIE_gtv                                  38.744658
#
#                                 original_shape_Maximum3DDiameter  \
# ID
# Patient38_IRM_simu_mridian_gtv                         68.904864
# Patient38_mridian_ttt_2_gtv                            69.633631
# Patient38_mridian_ttt_4_gtv                            68.904864
# Patient38_mridian_ttt_5_gtv                            68.904864
# Patient10_IRM_simu_GIE_gtv                             54.865907
#
#                                 original_shape_MeshVolume  \
# ID
# Patient38_IRM_simu_mridian_gtv                24300.18231
# Patient38_mridian_ttt_2_gtv                   24369.47426
# Patient38_mridian_ttt_4_gtv                   24464.75070
# Patient38_mridian_ttt_5_gtv                   24464.75070
# Patient10_IRM_simu_GIE_gtv                    18814.74989
#
#                                 original_shape_MinorAxisLength  ...  \
# ID                                                              ...
# Patient38_IRM_simu_mridian_gtv                       28.756943  ...
# Patient38_mridian_ttt_2_gtv                          29.299306  ...
# Patient38_mridian_ttt_4_gtv                          29.336497  ...
# Patient38_mridian_ttt_5_gtv                          29.336497  ...
# Patient10_IRM_simu_GIE_gtv                           31.065518  ...
#
#                                 original_ngtdm_Coarseness  \
# ID
# Patient38_IRM_simu_mridian_gtv                   0.001856
# Patient38_mridian_ttt_2_gtv                      0.001997
# Patient38_mridian_ttt_4_gtv                      0.002107
# Patient38_mridian_ttt_5_gtv                      0.002032
# Patient10_IRM_simu_GIE_gtv                       0.003128
#
#                                 original_ngtdm_Contrast  Patient Rxmic  \
# ID
# Patient38_IRM_simu_mridian_gtv                 0.175404     Patient 38
# Patient38_mridian_ttt_2_gtv                    0.128942     Patient 38
# Patient38_mridian_ttt_4_gtv                    0.153118     Patient 38
# Patient38_mridian_ttt_5_gtv                    0.169598     Patient 38
# Patient10_IRM_simu_GIE_gtv                     0.828998     Patient 10
#
#                                           Fraction  Volume  Récidive Locale  \
# ID
# Patient38_IRM_simu_mridian_gtv  Simulation mridian     GTV                0
# Patient38_mridian_ttt_2_gtv                      2     GTV                0
# Patient38_mridian_ttt_4_gtv                      4     GTV                0
# Patient38_mridian_ttt_5_gtv                      5     GTV                0
# Patient10_IRM_simu_GIE_gtv          Simulation GIE     GTV                0
#
#                                 Récidive Méta  Décès  Récidive  Évènement
# ID
# Patient38_IRM_simu_mridian_gtv              0      1         0          1
# Patient38_mridian_ttt_2_gtv                 0      1         0          1
# Patient38_mridian_ttt_4_gtv                 0      1         0          1
# Patient38_mridian_ttt_5_gtv                 0      1         0          1
# Patient10_IRM_simu_GIE_gtv                  1      1         1          1
#
# [5 rows x 89 columns]

# %%
repeatable_features = repeatable_features_gtv_df.columns[:-8]
print('Number of repeatable features:', len(repeatable_features))
# Out:
# Number of repeatable features: 81

# %% [markdown]
# ## Reproducibility analysis ICM

# %%
icc_file = "/home/tachennf/Documents/delta-rad/data/ICM_0.35T/results_icc.csv"
icc_df = pd.read_csv(icc_file)
icc_df.head()
# Out:
#                                   Feature    ICC
# 0              original_shape_SurfaceArea  0.964
# 1     original_firstorder_RootMeanSquared  0.316
# 2       original_shape_SurfaceVolumeRatio  0.985
# 3  original_shape_Maximum2DDiameterColumn  0.985
# 4                      original_glcm_Imc2  0.826

# %%
threshold = 0.75
reproductible_features = icc_df[icc_df['ICC'] >= threshold]

# %%
filtered_features = list(set(repeatable_features) & set(reproductible_features['Feature']))

# %% [markdown]
# ## Filtered
# ### SIMU GTV

# %%
simu_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/SIMU_GTV_extracted_features.csv', index_col=0)
filtered_simu_df = simu_df[filtered_features]
filtered_simu_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/SIMU_GTV_extracted_features_filtered.csv', index=True)
filtered_simu_df.head(5)
# Out:
#         original_glcm_Imc1  original_glcm_MCC  original_glcm_Idmn  \
# Mont10           -0.185596           0.768667            0.984429
# Mont1            -0.151995           0.851370            0.992793
# Mont32           -0.134421           0.722156            0.986995
# Mont23           -0.187577           0.685449            0.970460
# Mont35           -0.113947           0.638230            0.980838
#
#         original_shape_LeastAxisLength  original_glszm_GrayLevelNonUniformity  \
# Mont10                       17.135989                              21.302817
# Mont1                        35.181256                             101.988722
# Mont32                       40.949026                             172.910547
# Mont23                       13.893795                              20.456667
# Mont35                       22.430656                              64.375626
#
#         original_glcm_Id  original_shape_Maximum2DDiameterRow  \
# Mont10          0.321399                            24.450000
# Mont1           0.363196                            61.509557
# Mont32          0.393833                            73.548952
# Mont23          0.276643                            29.385243
# Mont35          0.386422                            51.776559
#
#         original_glszm_ZoneEntropy  original_shape_MajorAxisLength  \
# Mont10                    6.656038                       31.790638
# Mont1                     7.105892                       54.749558
# Mont32                    7.041696                       62.590622
# Mont23                    6.564863                       28.244188
# Mont35                    6.793305                       49.910227
#
#         original_glcm_SumEntropy  ...  original_glcm_Idm  \
# Mont10                  5.684689  ...           0.229505
# Mont1                   5.475522  ...           0.277431
# Mont32                  5.202837  ...           0.311482
# Mont23                  5.866106  ...           0.186202
# Mont35                  5.036108  ...           0.302476
#
#         original_glcm_Correlation  original_shape_Maximum2DDiameterColumn  \
# Mont10                   0.749476                               38.641659
# Mont1                    0.803610                               58.316653
# Mont32                   0.712656                               63.402600
# Mont23                   0.662519                               31.353676
# Mont35                   0.632135                               53.393386
#
#         original_shape_MinorAxisLength  original_glcm_InverseVariance  \
# Mont10                       18.763279                       0.234485
# Mont1                        37.477177                       0.282281
# Mont32                       49.578956                       0.310005
# Mont23                       22.568525                       0.190956
# Mont35                       33.979976                       0.303118
#
#         original_glcm_Idn  original_glrlm_RunVariance  \
# Mont10           0.914431                    0.081036
# Mont1            0.944154                    0.133726
# Mont32           0.924391                    0.165527
# Mont23           0.887534                    0.064811
# Mont35           0.908295                    0.151154
#
#         original_shape_Sphericity  original_gldm_DependenceNonUniformity  \
# Mont10                   0.681037                             282.849930
# Mont1                    0.689326                            1577.043466
# Mont32                   0.631497                            2553.441751
# Mont23                   0.676930                             301.555115
# Mont35                   0.672337                             778.419853
#
#         original_ngtdm_Coarseness
# Mont10                   0.009337
# Mont1                    0.001078
# Mont32                   0.000632
# Mont23                   0.007914
# Mont35                   0.002092
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F1

# %%
f1_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F1_GTV_extracted_features.csv', index_col=0)
filtered_f1_df = f1_df[filtered_features]
filtered_f1_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/F1_GTV_extracted_features_filtered.csv', index=True)
filtered_f1_df.head(5)
# Out:
#         original_glcm_Imc1  original_glcm_MCC  original_glcm_Idmn  \
# Mont10           -0.138617           0.701171            0.987736
# Mont1            -0.088577           0.579357            0.989280
# Mont32           -0.142011           0.738629            0.989535
# Mont23           -0.102650           0.617606            0.988008
# Mont35           -0.112005           0.628243            0.978214
#
#         original_shape_LeastAxisLength  original_glszm_GrayLevelNonUniformity  \
# Mont10                       16.939371                              21.488121
# Mont1                        37.022867                             107.954092
# Mont32                       40.172991                             162.262749
# Mont23                       20.243907                              31.411585
# Mont35                       21.405151                              55.045924
#
#         original_glcm_Id  original_shape_Maximum2DDiameterRow  \
# Mont10          0.380261                            24.934205
# Mont1           0.411821                            61.961444
# Mont32          0.390432                            70.014145
# Mont23          0.368730                            32.354576
# Mont35          0.415513                            50.319238
#
#         original_glszm_ZoneEntropy  original_shape_MajorAxisLength  \
# Mont10                    6.406298                       30.739393
# Mont1                     6.659970                       55.883453
# Mont32                    6.973166                       61.938562
# Mont23                    6.482737                       30.761015
# Mont35                    6.518267                       48.893465
#
#         original_glcm_SumEntropy  ...  original_glcm_Idm  \
# Mont10                  4.960418  ...           0.296037
# Mont1                   4.649499  ...           0.331288
# Mont32                  5.284571  ...           0.307003
# Mont23                  4.821089  ...           0.280911
# Mont35                  4.793306  ...           0.336271
#
#         original_glcm_Correlation  original_shape_Maximum2DDiameterColumn  \
# Mont10                   0.612915                               39.693094
# Mont1                    0.566427                               59.086095
# Mont32                   0.732849                               62.473883
# Mont23                   0.558597                               35.111275
# Mont35                   0.623742                               52.565921
#
#         original_shape_MinorAxisLength  original_glcm_InverseVariance  \
# Mont10                       20.810471                       0.291859
# Mont1                        37.647831                       0.331064
# Mont32                       48.291513                       0.308264
# Mont23                       26.427086                       0.278294
# Mont35                       33.502156                       0.332824
#
#         original_glcm_Idn  original_glrlm_RunVariance  \
# Mont10           0.926715                    0.132069
# Mont1            0.929797                    0.182952
# Mont32           0.931378                    0.161227
# Mont23           0.925352                    0.127815
# Mont35           0.903208                    0.180649
#
#         original_shape_Sphericity  original_gldm_DependenceNonUniformity  \
# Mont10                   0.676434                             227.710900
# Mont1                    0.691686                            1493.445121
# Mont32                   0.643833                            2446.589085
# Mont23                   0.694870                             367.889827
# Mont35                   0.671900                             638.320630
#
#         original_ngtdm_Coarseness
# Mont10                   0.006769
# Mont1                    0.000765
# Mont32                   0.000682
# Mont23                   0.003715
# Mont35                   0.002230
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F2

# %%
f2_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F2_GTV_extracted_features.csv', index_col=0)
filtered_f2_df = f2_df[filtered_features]
filtered_f2_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/F2_GTV_extracted_features_filtered.csv', index=True)
filtered_f2_df.head(5)
# Out:
#         original_glcm_Imc1  original_glcm_MCC  original_glcm_Idmn  \
# Mont10           -0.139393           0.695313            0.987641
# Mont1            -0.101772           0.591998            0.992191
# Mont32           -0.162097           0.777673            0.989949
# Mont23           -0.115533           0.737797            0.992469
# Mont35           -0.102581           0.583984            0.980997
#
#         original_shape_LeastAxisLength  original_glszm_GrayLevelNonUniformity  \
# Mont10                       16.942794                              24.022847
# Mont1                        36.409011                              80.053883
# Mont32                       40.613126                             158.479787
# Mont23                       15.463839                              11.880000
# Mont35                       21.466143                              52.643766
#
#         original_glcm_Id  original_shape_Maximum2DDiameterRow  \
# Mont10          0.323467                            24.934205
# Mont1           0.467803                            60.133526
# Mont32          0.415487                            71.960393
# Mont23          0.544459                            28.466726
# Mont35          0.426970                            51.027071
#
#         original_glszm_ZoneEntropy  original_shape_MajorAxisLength  \
# Mont10                    6.462259                       30.306458
# Mont1                     6.430057                       53.926352
# Mont32                    7.015145                       63.493738
# Mont23                    5.640876                       26.337113
# Mont35                    6.366945                       49.476323
#
#         original_glcm_SumEntropy  ...  original_glcm_Idm  \
# Mont10                  5.259862  ...           0.232548
# Mont1                   4.343008  ...           0.398250
# Mont32                  5.228857  ...           0.336727
# Mont23                  3.671647  ...           0.494724
# Mont35                  4.657180  ...           0.350564
#
#         original_glcm_Correlation  original_shape_Maximum2DDiameterColumn  \
# Mont10                   0.580974                               39.390730
# Mont1                    0.580109                               58.362195
# Mont32                   0.773830                               62.473883
# Mont23                   0.557676                               29.922822
# Mont35                   0.573282                               51.776559
#
#         original_shape_MinorAxisLength  original_glcm_InverseVariance  \
# Mont10                       21.019640                       0.233412
# Mont1                        36.782330                       0.386638
# Mont32                       48.505834                       0.332476
# Mont23                       23.431648                       0.446460
# Mont35                       32.209942                       0.345334
#
#         original_glcm_Idn  original_glrlm_RunVariance  \
# Mont10           0.924620                    0.092058
# Mont1            0.939675                    0.254731
# Mont32           0.932965                    0.193831
# Mont23           0.943804                    0.352682
# Mont35           0.910163                    0.189859
#
#         original_shape_Sphericity  original_gldm_DependenceNonUniformity  \
# Mont10                   0.707340                             288.051771
# Mont1                    0.709575                            1131.889952
# Mont32                   0.651377                            2341.528504
# Mont23                   0.686003                             115.140866
# Mont35                   0.660070                             580.734433
#
#         original_ngtdm_Coarseness
# Mont10                   0.006195
# Mont1                    0.000851
# Mont32                   0.000692
# Mont23                   0.005996
# Mont35                   0.002147
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F3

# %%
f3_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F3_GTV_extracted_features.csv', index_col=0)
filtered_f3_df = f3_df[filtered_features]   
filtered_f3_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/F3_GTV_extracted_features_filtered.csv', index=True)
filtered_f3_df.head(5)
# Out:
#         original_glcm_Imc1  original_glcm_MCC  original_glcm_Idmn  \
# Mont10           -0.129976           0.620549            0.982846
# Mont1            -0.136602           0.722565            0.988327
# Mont32           -0.155654           0.776997            0.987989
# Mont23           -0.133883           0.712352            0.989468
# Mont35           -0.100811           0.588114            0.982705
#
#         original_shape_LeastAxisLength  original_glszm_GrayLevelNonUniformity  \
# Mont10                       17.897686                              22.932021
# Mont1                        34.782342                              92.787534
# Mont32                       42.230031                             191.752812
# Mont23                       16.092230                              21.725051
# Mont35                       21.445582                              59.628821
#
#         original_glcm_Id  original_shape_Maximum2DDiameterRow  \
# Mont10          0.334070                            25.461414
# Mont1           0.394757                            60.133526
# Mont32          0.386600                            76.731287
# Mont23          0.339539                            29.158326
# Mont35          0.415239                            52.490050
#
#         original_glszm_ZoneEntropy  original_shape_MajorAxisLength  \
# Mont10                    6.625440                       31.438160
# Mont1                     6.958285                       54.548199
# Mont32                    7.124642                       64.453945
# Mont23                    6.442271                       26.742443
# Mont35                    6.447905                       50.479683
#
#         original_glcm_SumEntropy  ...  original_glcm_Idm  \
# Mont10                  5.239984  ...           0.242410
# Mont1                   5.130144  ...           0.311252
# Mont32                  5.420063  ...           0.302946
# Mont23                  5.086413  ...           0.248779
# Mont35                  4.706073  ...           0.336209
#
#         original_glcm_Correlation  original_shape_Maximum2DDiameterColumn  \
# Mont10                   0.598448                               39.693094
# Mont1                    0.712587                               57.026710
# Mont32                   0.772222                               64.048838
# Mont23                   0.623170                               29.967185
# Mont35                   0.581429                               52.006963
#
#         original_shape_MinorAxisLength  original_glcm_InverseVariance  \
# Mont10                       21.118184                       0.245833
# Mont1                        35.406433                       0.311218
# Mont32                       50.952983                       0.305179
# Mont23                       23.230155                       0.252038
# Mont35                       33.182060                       0.335536
#
#         original_glcm_Idn  original_glrlm_RunVariance  \
# Mont10           0.911542                    0.093503
# Mont1            0.926468                    0.160450
# Mont32           0.926607                    0.158433
# Mont23           0.928920                    0.096897
# Mont35           0.913184                    0.180326
#
#         original_shape_Sphericity  original_gldm_DependenceNonUniformity  \
# Mont10                   0.696081                             318.878499
# Mont1                    0.713131                            1370.770690
# Mont32                   0.637624                            2964.780474
# Mont23                   0.678925                             268.500344
# Mont35                   0.669381                             659.529671
#
#         original_ngtdm_Coarseness
# Mont10                   0.005896
# Mont1                    0.001093
# Mont32                   0.000628
# Mont23                   0.006053
# Mont35                   0.001933
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F4

# %%
f4_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F4_GTV_extracted_features.csv', index_col=0)
filtered_f4_df = f4_df[filtered_features]
filtered_f4_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/F4_GTV_extracted_features_filtered.csv', index=True)
filtered_f4_df.head(5)
# Out:
#         original_glcm_Imc1  original_glcm_MCC  original_glcm_Idmn  \
# Mont10           -0.138305           0.653136            0.985643
# Mont1            -0.117200           0.647125            0.991347
# Mont32           -0.150686           0.749896            0.987992
# Mont23           -0.137379           0.709077            0.986321
# Mont35           -0.115354           0.624696            0.982362
#
#         original_shape_LeastAxisLength  original_glszm_GrayLevelNonUniformity  \
# Mont10                       16.335832                              13.239583
# Mont1                        34.631655                              82.289845
# Mont32                       41.557741                             163.871176
# Mont23                       15.632214                              25.031915
# Mont35                       21.527041                              53.797605
#
#         original_glcm_Id  original_shape_Maximum2DDiameterRow  \
# Mont10          0.471822                            23.338048
# Mont1           0.426564                            60.133526
# Mont32          0.406371                            75.139287
# Mont23          0.361782                            31.353676
# Mont35          0.422021                            50.345631
#
#         original_glszm_ZoneEntropy  original_shape_MajorAxisLength  \
# Mont10                    6.180073                       30.367371
# Mont1                     6.645762                       54.390477
# Mont32                    7.079818                       62.522376
# Mont23                    6.433935                       31.036862
# Mont35                    6.600852                       49.458548
#
#         original_glcm_SumEntropy  ...  original_glcm_Idm  \
# Mont10                  4.431575  ...           0.402823
# Mont1                   4.746066  ...           0.348147
# Mont32                  5.230818  ...           0.325630
# Mont23                  5.023729  ...           0.275863
# Mont35                  4.755614  ...           0.343842
#
#         original_glcm_Correlation  original_shape_Maximum2DDiameterColumn  \
# Mont10                   0.618228                               37.912833
# Mont1                    0.638401                               57.629203
# Mont32                   0.746545                               66.491214
# Mont23                   0.655636                               34.997584
# Mont35                   0.618502                               52.185463
#
#         original_shape_MinorAxisLength  original_glcm_InverseVariance  \
# Mont10                       19.688823                       0.382073
# Mont1                        35.857314                       0.343942
# Mont32                       49.673592                       0.323180
# Mont23                       26.764078                       0.279728
# Mont35                       35.305503                       0.338759
#
#         original_glcm_Idn  original_glrlm_RunVariance  \
# Mont10           0.920128                    0.211956
# Mont1            0.936169                    0.200435
# Mont32           0.926908                    0.178008
# Mont23           0.923834                    0.116528
# Mont35           0.912427                    0.182815
#
#         original_shape_Sphericity  original_gldm_DependenceNonUniformity  \
# Mont10                   0.703437                             156.514695
# Mont1                    0.692931                            1190.233647
# Mont32                   0.622666                            2516.324634
# Mont23                   0.703498                             300.067374
# Mont35                   0.645618                             647.735473
#
#         original_ngtdm_Coarseness
# Mont10                   0.007557
# Mont1                    0.001012
# Mont32                   0.000665
# Mont23                   0.004746
# Mont35                   0.002134
#
# [5 rows x 49 columns]

# %% [markdown]
# ### F5

# %%
f5_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/Madrid/raw_csv/F5_GTV_extracted_features.csv', index_col=0)
filtered_f5_df = f5_df[filtered_features]
filtered_f5_df.to_csv('/home/tachennf/Documents/delta-rad/data/Madrid/filtered_csv/F5_GTV_extracted_features_filtered.csv', index=True) 
filtered_f5_df.head(5)
# Out:
#         original_glcm_Imc1  original_glcm_MCC  original_glcm_Idmn  \
# Mont10           -0.143553           0.665357            0.986819
# Mont1            -0.140289           0.690366            0.991216
# Mont32           -0.158930           0.806207            0.987382
# Mont23           -0.098510           0.535397            0.980332
# Mont35           -0.107190           0.607076            0.981746
#
#         original_shape_LeastAxisLength  original_glszm_GrayLevelNonUniformity  \
# Mont10                       15.769588                              14.738516
# Mont1                        35.311028                              74.439239
# Mont32                       40.329935                             185.419844
# Mont23                       15.372824                              23.202586
# Mont35                       20.934146                              57.141631
#
#         original_glcm_Id  original_shape_Maximum2DDiameterRow  \
# Mont10          0.401087                            23.338048
# Mont1           0.463252                            62.388769
# Mont32          0.355393                            71.960393
# Mont23          0.345979                            29.967185
# Mont35          0.409527                            49.574515
#
#         original_glszm_ZoneEntropy  original_shape_MajorAxisLength  \
# Mont10                    6.362329                       30.700193
# Mont1                     6.621979                       55.176088
# Mont32                    7.266024                       62.433672
# Mont23                    6.353117                       27.131478
# Mont35                    6.536831                       47.573888
#
#         original_glcm_SumEntropy  ...  original_glcm_Idm  \
# Mont10                  4.812427  ...           0.317888
# Mont1                   4.654728  ...           0.393456
# Mont32                  5.601014  ...           0.266644
# Mont23                  4.826156  ...           0.255265
# Mont35                  4.809807  ...           0.329160
#
#         original_glcm_Correlation  original_shape_Maximum2DDiameterColumn  \
# Mont10                   0.622876                               37.912833
# Mont1                    0.683100                               60.661409
# Mont32                   0.792630                               63.402600
# Mont23                   0.479611                               31.012865
# Mont35                   0.599191                               51.157077
#
#         original_shape_MinorAxisLength  original_glcm_InverseVariance  \
# Mont10                       19.779984                       0.319477
# Mont1                        38.135641                       0.380220
# Mont32                       49.477355                       0.271523
# Mont23                       23.749177                       0.266497
# Mont35                       33.940236                       0.324510
#
#         original_glcm_Idn  original_glrlm_RunVariance  \
# Mont10           0.922850                    0.135732
# Mont1            0.937363                    0.261411
# Mont32           0.923104                    0.124697
# Mont23           0.904086                    0.093723
# Mont35           0.910754                    0.175977
#
#         original_shape_Sphericity  original_gldm_DependenceNonUniformity  \
# Mont10                   0.689727                             189.332248
# Mont1                    0.701623                            1148.392684
# Mont32                   0.640953                            3051.322268
# Mont23                   0.668731                             271.070671
# Mont35                   0.680370                             648.438452
#
#         original_ngtdm_Coarseness
# Mont10                   0.008317
# Mont1                    0.000973
# Mont32                   0.000663
# Mont23                   0.005908
# Mont35                   0.002102
#
# [5 rows x 49 columns]
