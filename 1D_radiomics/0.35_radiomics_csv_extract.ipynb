# %% [markdown]
# # Radiomics csv extraction
# Create csv file by fraction (or delta-fraction) from 'filtered_features_gtv.xlsx'

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Clinical data

# %%
clinical_data_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/clinical_data_clean.csv', index_col=0, sep=';')
clinical_data_df
# Out:
#         Date diagnostic Date debut chimio date fin de ttt RT  \
# 1403778      13/11/2018        01/01/2019         28/10/2019
# 1906503      21/03/2019        01/04/2019         19/11/2019
# 1904130      04/07/2019        10/07/2019         11/12/2019
# 1905976      22/01/2019        01/02/2019         16/10/2019
# 1907649      28/05/2019        13/06/2019         08/01/2020
# ...                 ...               ...                ...
# 2204364      17/01/2022        05/02/2022         27/07/2022
# 2201397      16/03/2022        06/04/2022         05/08/2022
# 2204013      02/12/2021        15/01/2022         05/08/2022
# 2102092      23/02/2021        25/03/2021         01/09/2021
# 2002943      10/10/2020        20/10/2020         03/09/2021
#
#         Date de recidive locale   Situation de la recidive locale   \
# 1403778                      NaN                               NaN
# 1906503               01/07/2020                               1.0
# 1904130                      NaN                               NaN
# 1905976                      NaN                               NaN
# 1907649                      NaN                               NaN
# ...                          ...                               ...
# 2204364                      NaN                               NaN
# 2201397                      NaN                               NaN
# 2204013                      NaN                               NaN
# 2102092               02/12/2021                               NaN
# 2002943                      NaN                               NaN
#
#         Date de recidive méta  Date de deces  Cause de Deces   \
# 1403778             18/12/2019     28/05/2020               2
# 1906503             15/04/2021     27/08/2021               2
# 1904130             18/09/2020            NaN             NaN
# 1905976             06/03/2020     06/08/2020               5
# 1907649             30/04/2020     01/08/2020               2
# ...                        ...            ...             ...
# 2204364                    NaN            NaN             NaN
# 2201397             27/09/2022            NaN             NaN
# 2204013                    NaN            NaN             NaN
# 2102092                    NaN     06/04/2022               1
# 2002943             18/10/2021            NaN             NaN
#
#         Date dernières nouvelles
# 1403778                      NaN
# 1906503                      NaN
# 1904130               06/04/2023
# 1905976                      NaN
# 1907649                      NaN
# ...                          ...
# 2204364               04/04/2023
# 2201397               28/02/2023
# 2204013               06/03/2023
# 2102092                      NaN
# 2002943               18/10/2021
#
# [91 rows x 9 columns]

# %%
print(clinical_data_df['Situation de la recidive locale '].value_counts())
# Out:
# Situation de la recidive locale
# 1.0    3
# 2.0    3
# Name: count, dtype: int64

# %% [markdown]
# ## Transform to date format

# %%
date_outcome_df = pd.DataFrame(index=clinical_data_df.index, columns=['date fin de ttt RT', 'Date de recidive locale '])
date_outcome_df['date fin de ttt RT'] = pd.to_datetime(clinical_data_df['date fin de ttt RT'], format="%d/%m/%Y", errors='coerce')
date_outcome_df['Date de recidive locale '] = pd.to_datetime(clinical_data_df['Date de recidive locale '], format="%d/%m/%Y", errors='coerce')
date_outcome_df['Date dernières nouvelles'] = pd.to_datetime(clinical_data_df['Date dernières nouvelles'], format="%d/%m/%Y", errors='coerce')
date_outcome_df.head()
# Out:
#         date fin de ttt RT Date de recidive locale  Date dernières nouvelles
# 1403778         2019-10-28                      NaT                      NaT
# 1906503         2019-11-19               2020-07-01                      NaT
# 1904130         2019-12-11                      NaT               2023-04-06
# 1905976         2019-10-16                      NaT                      NaT
# 1907649         2020-01-08                      NaT                      NaT

# %% [markdown]
# ## One year LC status

# %%
date_outcome_df['difference end RT and local recurrence'] = (date_outcome_df['Date de recidive locale '] - date_outcome_df['date fin de ttt RT']).dt.days
one_year_in_days = 365

# %%
date_outcome_df['one_year_status'] = date_outcome_df['difference end RT and local recurrence'] <= one_year_in_days
date_outcome_df
# Out:
#         date fin de ttt RT Date de recidive locale  Date dernières nouvelles  \
# 1403778         2019-10-28                      NaT                      NaT
# 1906503         2019-11-19               2020-07-01                      NaT
# 1904130         2019-12-11                      NaT               2023-04-06
# 1905976         2019-10-16                      NaT                      NaT
# 1907649         2020-01-08                      NaT                      NaT
# ...                    ...                      ...                      ...
# 2204364         2022-07-27                      NaT               2023-04-04
# 2201397         2022-08-05                      NaT               2023-02-28
# 2204013         2022-08-05                      NaT               2023-03-06
# 2102092         2021-09-01               2021-12-02                      NaT
# 2002943         2021-09-03                      NaT               2021-10-18
#
#          difference end RT and local recurrence  one_year_status
# 1403778                                     NaN            False
# 1906503                                   225.0             True
# 1904130                                     NaN            False
# 1905976                                     NaN            False
# 1907649                                     NaN            False
# ...                                         ...              ...
# 2204364                                     NaN            False
# 2201397                                     NaN            False
# 2204013                                     NaN            False
# 2102092                                    92.0             True
# 2002943                                     NaN            False
#
# [91 rows x 5 columns]

# %%
print(date_outcome_df['one_year_status'].value_counts())
# Out:
# one_year_status
# False    77
# True     14
# Name: count, dtype: int64

# %% [markdown]
# ### Follow-up

# %%
date_outcome_df['difference today and end RT'] = (date_outcome_df['Date dernières nouvelles'] - date_outcome_df['date fin de ttt RT']).dt.days
date_outcome_df
# Out:
#         date fin de ttt RT Date de recidive locale  Date dernières nouvelles  \
# 1403778         2019-10-28                      NaT                      NaT
# 1906503         2019-11-19               2020-07-01                      NaT
# 1904130         2019-12-11                      NaT               2023-04-06
# 1905976         2019-10-16                      NaT                      NaT
# 1907649         2020-01-08                      NaT                      NaT
# ...                    ...                      ...                      ...
# 2204364         2022-07-27                      NaT               2023-04-04
# 2201397         2022-08-05                      NaT               2023-02-28
# 2204013         2022-08-05                      NaT               2023-03-06
# 2102092         2021-09-01               2021-12-02                      NaT
# 2002943         2021-09-03                      NaT               2021-10-18
#
#          difference end RT and local recurrence  one_year_status  \
# 1403778                                     NaN            False
# 1906503                                   225.0             True
# 1904130                                     NaN            False
# 1905976                                     NaN            False
# 1907649                                     NaN            False
# ...                                         ...              ...
# 2204364                                     NaN            False
# 2201397                                     NaN            False
# 2204013                                     NaN            False
# 2102092                                    92.0             True
# 2002943                                     NaN            False
#
#          difference today and end RT
# 1403778                          NaN
# 1906503                          NaN
# 1904130                       1212.0
# 1905976                          NaN
# 1907649                          NaN
# ...                              ...
# 2204364                        251.0
# 2201397                        207.0
# 2204013                        213.0
# 2102092                          NaN
# 2002943                         45.0
#
# [91 rows x 6 columns]

# %%
date_outcome_df.sort_index(inplace=True)
date_outcome_df
# Out:
#         date fin de ttt RT Date de recidive locale  Date dernières nouvelles  \
# 400444          2022-04-20                      NaT                      NaT
# 601828          2022-07-19                      NaT                      NaT
# 1000305         2022-05-23               2022-10-05               2023-04-04
# 1104589         2020-05-25                      NaT                      NaT
# 1403778         2019-10-28                      NaT                      NaT
# ...                    ...                      ...                      ...
# 8203368         2021-09-17                      NaT               2023-02-07
# 8403324         2021-09-08                      NaT                      NaT
# 8502745         2021-04-14                      NaT                      NaT
# 9604419         2021-08-27                      NaT                      NaT
# 9802362         2020-07-21                      NaT                      NaT
#
#          difference end RT and local recurrence  one_year_status  \
# 400444                                      NaN            False
# 601828                                      NaN            False
# 1000305                                   135.0             True
# 1104589                                     NaN            False
# 1403778                                     NaN            False
# ...                                         ...              ...
# 8203368                                     NaN            False
# 8403324                                     NaN            False
# 8502745                                     NaN            False
# 9604419                                     NaN            False
# 9802362                                     NaN            False
#
#          difference today and end RT
# 400444                           NaN
# 601828                           NaN
# 1000305                        316.0
# 1104589                          NaN
# 1403778                          NaN
# ...                              ...
# 8203368                        508.0
# 8403324                          NaN
# 8502745                          NaN
# 9604419                          NaN
# 9802362                          NaN
#
# [91 rows x 6 columns]

# %%
date_outcome_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/date_outcome_df.csv', sep=';', index=True)

# %% [markdown]
# ### Patient ID

# %%
liste_patients_df = pd.read_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/liste_id_patients.csv', index_col=0, sep=';')
liste_patients_df
# Out:
#              ID ICM
# Patient 1   1403778
# Patient 2   1906503
# Patient 3   1904130
# Patient 4   1905976
# Patient 5   1904380
# ...             ...
# Patient 82  1705579
# Patient 83  2204364
# Patient 84  2201397
# Patient 85  2204013
# Patient 86  2000339
#
# [86 rows x 1 columns]

# %%
liste_patients_df.sort_values(by='ID ICM', inplace=True)
liste_patients_df
# Out:
#              ID ICM
# Patient 73   400444
# Patient 81   601828
# Patient 76  1000305
# Patient 16  1104589
# Patient 1   1403778
# ...             ...
# Patient 85  2204013
# Patient 83  2204364
# Patient 52  8203368
# Patient 50  8403324
# Patient 47  9604419
#
# [86 rows x 1 columns]

# %%
# remove patient in clinical_data_df that are not in liste_patients_df
filtered_date_outcome_df = date_outcome_df[date_outcome_df.index.isin(liste_patients_df['ID ICM'])]
filtered_date_outcome_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/filtered_date_outcome_df.csv', sep=';', index=True)

# %%
# remove the patients of liste_patients_df that are not in clinical_data_df
filtered_liste_patients_df = liste_patients_df[liste_patients_df['ID ICM'].isin(filtered_date_outcome_df.index)]

# %%
# for each patient in date_outcome_df, get his index name in liste_patients_df
filtered_date_outcome_df.index = filtered_liste_patients_df.index 
filtered_date_outcome_df
# Out:
#            date fin de ttt RT Date de recidive locale   \
# Patient 73         2022-04-20                      NaT
# Patient 81         2022-07-19                      NaT
# Patient 76         2022-05-23               2022-10-05
# Patient 16         2020-05-25                      NaT
# Patient 1          2019-10-28                      NaT
# ...                       ...                      ...
# Patient 85         2022-08-05                      NaT
# Patient 83         2022-07-27                      NaT
# Patient 52         2021-09-17                      NaT
# Patient 50         2021-09-08                      NaT
# Patient 47         2021-08-27                      NaT
#
#            Date dernières nouvelles  difference end RT and local recurrence  \
# Patient 73                      NaT                                     NaN
# Patient 81                      NaT                                     NaN
# Patient 76               2023-04-04                                   135.0
# Patient 16                      NaT                                     NaN
# Patient 1                       NaT                                     NaN
# ...                             ...                                     ...
# Patient 85               2023-03-06                                     NaN
# Patient 83               2023-04-04                                     NaN
# Patient 52               2023-02-07                                     NaN
# Patient 50                      NaT                                     NaN
# Patient 47                      NaT                                     NaN
#
#             one_year_status  difference today and end RT
# Patient 73            False                          NaN
# Patient 81            False                          NaN
# Patient 76             True                        316.0
# Patient 16            False                          NaN
# Patient 1             False                          NaN
# ...                     ...                          ...
# Patient 85            False                        213.0
# Patient 83            False                        251.0
# Patient 52            False                        508.0
# Patient 50            False                          NaN
# Patient 47            False                          NaN
#
# [85 rows x 6 columns]

# %%
# create one dataframe with the index filtered_date_outcome_df and the one_year_status (but binary 0 or 1 instead of True and False) 
one_year_status_df = pd.DataFrame(index=filtered_date_outcome_df.index, columns=['one_year_status'])
one_year_status_df['one_year_status'] = filtered_date_outcome_df['one_year_status'].astype(int)
one_year_status_df
# Out:
#             one_year_status
# Patient 73                0
# Patient 81                0
# Patient 76                1
# Patient 16                0
# Patient 1                 0
# ...                     ...
# Patient 85                0
# Patient 83                0
# Patient 52                0
# Patient 50                0
# Patient 47                0
#
# [85 rows x 1 columns]

# %%
print(one_year_status_df['one_year_status'].value_counts())
# Out:
# one_year_status
# 0    71
# 1    14
# Name: count, dtype: int64

# %%
one_year_status_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/outcomes.csv', sep=',', index=True)

# %% [markdown]
# ## Repeatability analysis

# %%
repeat_file = "/home/tachennf/Documents/delta-rad/data/ICM_0.35T/filtered_features_gtv.xlsx"
repeatable_features_gtv_df = pd.read_excel(repeat_file, index_col=0)
repeatable_features_gtv_df.head()
# Out:
#                                 original_shape_Elongation  \
# ID
# Patient38_IRM_simu_mridian_gtv                   0.431793
# Patient38_mridian_ttt_2_gtv                      0.442144
# Patient38_mridian_ttt_4_gtv                      0.442374
# Patient38_mridian_ttt_5_gtv                      0.442374
# Patient10_IRM_simu_GIE_gtv                       0.672158
#
#                                 original_shape_Flatness  \
# ID
# Patient38_IRM_simu_mridian_gtv                 0.370555
# Patient38_mridian_ttt_2_gtv                    0.371772
# Patient38_mridian_ttt_4_gtv                    0.371341
# Patient38_mridian_ttt_5_gtv                    0.371341
# Patient10_IRM_simu_GIE_gtv                     0.549602
#
#                                 original_shape_LeastAxisLength  \
# ID
# Patient38_IRM_simu_mridian_gtv                       24.678556
# Patient38_mridian_ttt_2_gtv                          24.636047
# Patient38_mridian_ttt_4_gtv                          24.625888
# Patient38_mridian_ttt_5_gtv                          24.625888
# Patient10_IRM_simu_GIE_gtv                           25.401274
#
#                                 original_shape_MajorAxisLength  \
# ID
# Patient38_IRM_simu_mridian_gtv                       66.598953
# Patient38_mridian_ttt_2_gtv                          66.266497
# Patient38_mridian_ttt_4_gtv                          66.316118
# Patient38_mridian_ttt_5_gtv                          66.316118
# Patient10_IRM_simu_GIE_gtv                           46.217551
#
#                                 original_shape_Maximum2DDiameterColumn  \
# ID
# Patient38_IRM_simu_mridian_gtv                               53.068955
# Patient38_mridian_ttt_2_gtv                                  52.185463
# Patient38_mridian_ttt_4_gtv                                  53.068955
# Patient38_mridian_ttt_5_gtv                                  53.068955
# Patient10_IRM_simu_GIE_gtv                                   46.704549
#
#                                 original_shape_Maximum2DDiameterRow  \
# ID
# Patient38_IRM_simu_mridian_gtv                            57.813322
# Patient38_mridian_ttt_2_gtv                               57.813322
# Patient38_mridian_ttt_4_gtv                               57.813322
# Patient38_mridian_ttt_5_gtv                               57.813322
# Patient10_IRM_simu_GIE_gtv                                54.477126
#
#                                 original_shape_Maximum2DDiameterSlice  \
# ID
# Patient38_IRM_simu_mridian_gtv                              47.606047
# Patient38_mridian_ttt_2_gtv                                 47.606047
# Patient38_mridian_ttt_4_gtv                                 47.606047
# Patient38_mridian_ttt_5_gtv                                 47.606047
# Patient10_IRM_simu_GIE_gtv                                  38.744658
#
#                                 original_shape_Maximum3DDiameter  \
# ID
# Patient38_IRM_simu_mridian_gtv                         68.904864
# Patient38_mridian_ttt_2_gtv                            69.633631
# Patient38_mridian_ttt_4_gtv                            68.904864
# Patient38_mridian_ttt_5_gtv                            68.904864
# Patient10_IRM_simu_GIE_gtv                             54.865907
#
#                                 original_shape_MeshVolume  \
# ID
# Patient38_IRM_simu_mridian_gtv                24300.18231
# Patient38_mridian_ttt_2_gtv                   24369.47426
# Patient38_mridian_ttt_4_gtv                   24464.75070
# Patient38_mridian_ttt_5_gtv                   24464.75070
# Patient10_IRM_simu_GIE_gtv                    18814.74989
#
#                                 original_shape_MinorAxisLength  ...  \
# ID                                                              ...
# Patient38_IRM_simu_mridian_gtv                       28.756943  ...
# Patient38_mridian_ttt_2_gtv                          29.299306  ...
# Patient38_mridian_ttt_4_gtv                          29.336497  ...
# Patient38_mridian_ttt_5_gtv                          29.336497  ...
# Patient10_IRM_simu_GIE_gtv                           31.065518  ...
#
#                                 original_ngtdm_Coarseness  \
# ID
# Patient38_IRM_simu_mridian_gtv                   0.001856
# Patient38_mridian_ttt_2_gtv                      0.001997
# Patient38_mridian_ttt_4_gtv                      0.002107
# Patient38_mridian_ttt_5_gtv                      0.002032
# Patient10_IRM_simu_GIE_gtv                       0.003128
#
#                                 original_ngtdm_Contrast  Patient Rxmic  \
# ID
# Patient38_IRM_simu_mridian_gtv                 0.175404     Patient 38
# Patient38_mridian_ttt_2_gtv                    0.128942     Patient 38
# Patient38_mridian_ttt_4_gtv                    0.153118     Patient 38
# Patient38_mridian_ttt_5_gtv                    0.169598     Patient 38
# Patient10_IRM_simu_GIE_gtv                     0.828998     Patient 10
#
#                                           Fraction  Volume  Récidive Locale  \
# ID
# Patient38_IRM_simu_mridian_gtv  Simulation mridian     GTV                0
# Patient38_mridian_ttt_2_gtv                      2     GTV                0
# Patient38_mridian_ttt_4_gtv                      4     GTV                0
# Patient38_mridian_ttt_5_gtv                      5     GTV                0
# Patient10_IRM_simu_GIE_gtv          Simulation GIE     GTV                0
#
#                                 Récidive Méta  Décès  Récidive  Évènement
# ID
# Patient38_IRM_simu_mridian_gtv              0      1         0          1
# Patient38_mridian_ttt_2_gtv                 0      1         0          1
# Patient38_mridian_ttt_4_gtv                 0      1         0          1
# Patient38_mridian_ttt_5_gtv                 0      1         0          1
# Patient10_IRM_simu_GIE_gtv                  1      1         1          1
#
# [5 rows x 89 columns]

# %%
repeatable_features = repeatable_features_gtv_df.columns[:-8]
print('Number of repeatable features:', len(repeatable_features))
# Out:
# Number of repeatable features: 81

# %%
print(repeatable_features)
# Out:
# Index(['original_shape_Elongation', 'original_shape_Flatness',
#        'original_shape_LeastAxisLength', 'original_shape_MajorAxisLength',
#        'original_shape_Maximum2DDiameterColumn',
#        'original_shape_Maximum2DDiameterRow',
#        'original_shape_Maximum2DDiameterSlice',
#        'original_shape_Maximum3DDiameter', 'original_shape_MeshVolume',
#        'original_shape_MinorAxisLength', 'original_shape_Sphericity',
#        'original_shape_SurfaceArea', 'original_shape_SurfaceVolumeRatio',
#        'original_shape_VoxelVolume', 'original_firstorder_10Percentile',
#        'original_firstorder_90Percentile', 'original_firstorder_Energy',
#        'original_firstorder_Entropy', 'original_firstorder_InterquartileRange',
#        'original_firstorder_Kurtosis', 'original_firstorder_Maximum',
#        'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean',
#        'original_firstorder_Median', 'original_firstorder_Range',
#        'original_firstorder_RobustMeanAbsoluteDeviation',
#        'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness',
#        'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity',
#        'original_glcm_ClusterShade', 'original_glcm_Contrast',
#        'original_glcm_Correlation', 'original_glcm_DifferenceAverage',
#        'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance',
#        'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Idmn',
#        'original_glcm_Idn', 'original_glcm_Imc1', 'original_glcm_Imc2',
#        'original_glcm_InverseVariance', 'original_glcm_JointAverage',
#        'original_glcm_JointEnergy', 'original_glcm_JointEntropy',
#        'original_glcm_MCC', 'original_glcm_MaximumProbability',
#        'original_glcm_SumAverage', 'original_glcm_SumEntropy',
#        'original_glrlm_GrayLevelNonUniformity',
#        'original_glrlm_GrayLevelNonUniformityNormalized',
#        'original_glrlm_GrayLevelVariance', 'original_glrlm_LongRunEmphasis',
#        'original_glrlm_LongRunHighGrayLevelEmphasis',
#        'original_glrlm_RunEntropy', 'original_glrlm_RunLengthNonUniformity',
#        'original_glrlm_RunLengthNonUniformityNormalized',
#        'original_glrlm_RunPercentage', 'original_glrlm_RunVariance',
#        'original_glrlm_ShortRunEmphasis',
#        'original_glszm_GrayLevelNonUniformity',
#        'original_glszm_GrayLevelNonUniformityNormalized',
#        'original_glszm_GrayLevelVariance',
#        'original_glszm_LargeAreaHighGrayLevelEmphasis',
#        'original_glszm_SizeZoneNonUniformity',
#        'original_glszm_SizeZoneNonUniformityNormalized',
#        'original_glszm_SmallAreaEmphasis', 'original_glszm_ZoneEntropy',
#        'original_glszm_ZonePercentage', 'original_gldm_DependenceEntropy',
#        'original_gldm_DependenceNonUniformity',
#        'original_gldm_DependenceNonUniformityNormalized',
#        'original_gldm_DependenceVariance',
#        'original_gldm_GrayLevelNonUniformity',
#        'original_gldm_LargeDependenceEmphasis',
#        'original_gldm_LargeDependenceHighGrayLevelEmphasis',
#        'original_gldm_SmallDependenceEmphasis', 'original_ngtdm_Busyness',
#        'original_ngtdm_Coarseness', 'original_ngtdm_Contrast'],
#       dtype='object')

# %% [markdown]
# ## Reproductibility analysis

# %%
icc_file = "/home/tachennf/Documents/delta-rad/data/ICM_0.35T/results_icc.csv"
icc_df = pd.read_csv(icc_file)
icc_df.head()
# Out:
#                                   Feature    ICC
# 0              original_shape_SurfaceArea  0.964
# 1     original_firstorder_RootMeanSquared  0.316
# 2       original_shape_SurfaceVolumeRatio  0.985
# 3  original_shape_Maximum2DDiameterColumn  0.985
# 4                      original_glcm_Imc2  0.826

# %%
threshold = 0.75
reproductible_features = icc_df[icc_df['ICC'] >= threshold]
print('Number of reproductible features (with ICC >', threshold, ') :', len(reproductible_features))
# Out:
# Number of reproductible features (with ICC > 0.75 ) : 58

# %% [markdown]
# ## Repeatable and reproducible features

# %%
# intersection between repeatable features and reproductible features
filtered_features = list(set(repeatable_features) & set(reproductible_features['Feature']))
print('Number of repetable and reproducible features:', len(filtered_features))
# Out:
# Number of repetable and reproducible features: 49

# %% [markdown]
# Out of 107 features, only 49 are kept so we remove 58 features.

# %%
print(filtered_features)
# Out:
# ['original_glcm_JointEntropy', 'original_glcm_Idn', 'original_glcm_Id', 'original_shape_Maximum2DDiameterRow', 'original_glcm_MCC', 'original_glrlm_ShortRunEmphasis', 'original_shape_VoxelVolume', 'original_glrlm_GrayLevelNonUniformity', 'original_glcm_Imc1', 'original_glcm_InverseVariance', 'original_shape_SurfaceVolumeRatio', 'original_glcm_Imc2', 'original_gldm_LargeDependenceEmphasis', 'original_shape_Maximum3DDiameter', 'original_glrlm_RunLengthNonUniformityNormalized', 'original_gldm_DependenceNonUniformity', 'original_shape_Flatness', 'original_shape_Maximum2DDiameterColumn', 'original_glcm_Correlation', 'original_shape_MajorAxisLength', 'original_glcm_MaximumProbability', 'original_shape_MeshVolume', 'original_shape_LeastAxisLength', 'original_firstorder_Entropy', 'original_glcm_Idmn', 'original_firstorder_Uniformity', 'original_glrlm_RunEntropy', 'original_glcm_SumEntropy', 'original_shape_Elongation', 'original_shape_SurfaceArea', 'original_glszm_ZoneEntropy', 'original_glszm_GrayLevelNonUniformity', 'original_ngtdm_Coarseness', 'original_glszm_GrayLevelNonUniformityNormalized', 'original_glrlm_RunLengthNonUniformity', 'original_ngtdm_Busyness', 'original_glrlm_LongRunEmphasis', 'original_shape_MinorAxisLength', 'original_glrlm_RunVariance', 'original_glrlm_RunPercentage', 'original_glcm_Idm', 'original_shape_Sphericity', 'original_glrlm_GrayLevelNonUniformityNormalized', 'original_gldm_GrayLevelNonUniformity', 'original_shape_Maximum2DDiameterSlice', 'original_firstorder_Kurtosis', 'original_gldm_DependenceEntropy', 'original_glcm_JointEnergy', 'original_glszm_LargeAreaHighGrayLevelEmphasis']

# %% [markdown]
# ## Filter table

# %%
filtered_gtv_df = repeatable_features_gtv_df[repeatable_features_gtv_df.columns[:-8]].loc[:, filtered_features]
filtered_gtv_df
# Out:
#                                 original_glcm_JointEntropy  original_glcm_Idn  \
# ID
# Patient38_IRM_simu_mridian_gtv                    9.296847           0.912290
# Patient38_mridian_ttt_2_gtv                       8.881243           0.918255
# Patient38_mridian_ttt_4_gtv                       8.965991           0.917098
# Patient38_mridian_ttt_5_gtv                       9.331947           0.915969
# Patient10_IRM_simu_GIE_gtv                       11.692852           0.914240
# ...                                                    ...                ...
# Patient21_mridian_ttt_1_gtv                       9.417531           0.925365
# Patient21_mridian_ttt_2_gtv                       9.673882           0.928125
# Patient21_mridian_ttt_3_gtv                       9.363763           0.928359
# Patient21_mridian_ttt_4_gtv                       9.384238           0.924847
# Patient21_mridian_ttt_5_gtv                       9.195581           0.921789
#
#                                 original_glcm_Id  \
# ID
# Patient38_IRM_simu_mridian_gtv          0.286330
# Patient38_mridian_ttt_2_gtv             0.322940
# Patient38_mridian_ttt_4_gtv             0.329904
# Patient38_mridian_ttt_5_gtv             0.298745
# Patient10_IRM_simu_GIE_gtv              0.165475
# ...                                          ...
# Patient21_mridian_ttt_1_gtv             0.292583
# Patient21_mridian_ttt_2_gtv             0.291257
# Patient21_mridian_ttt_3_gtv             0.303768
# Patient21_mridian_ttt_4_gtv             0.301061
# Patient21_mridian_ttt_5_gtv             0.310585
#
#                                 original_shape_Maximum2DDiameterRow  \
# ID
# Patient38_IRM_simu_mridian_gtv                            57.813322
# Patient38_mridian_ttt_2_gtv                               57.813322
# Patient38_mridian_ttt_4_gtv                               57.813322
# Patient38_mridian_ttt_5_gtv                               57.813322
# Patient10_IRM_simu_GIE_gtv                                54.477126
# ...                                                             ...
# Patient21_mridian_ttt_1_gtv                               67.541819
# Patient21_mridian_ttt_2_gtv                               67.541819
# Patient21_mridian_ttt_3_gtv                               67.541819
# Patient21_mridian_ttt_4_gtv                               67.797028
# Patient21_mridian_ttt_5_gtv                               67.541819
#
#                                 original_glcm_MCC  \
# ID
# Patient38_IRM_simu_mridian_gtv           0.657849
# Patient38_mridian_ttt_2_gtv              0.689003
# Patient38_mridian_ttt_4_gtv              0.759629
# Patient38_mridian_ttt_5_gtv              0.730941
# Patient10_IRM_simu_GIE_gtv               0.806036
# ...                                           ...
# Patient21_mridian_ttt_1_gtv              0.698756
# Patient21_mridian_ttt_2_gtv              0.735026
# Patient21_mridian_ttt_3_gtv              0.722325
# Patient21_mridian_ttt_4_gtv              0.716552
# Patient21_mridian_ttt_5_gtv              0.725941
#
#                                 original_glrlm_ShortRunEmphasis  \
# ID
# Patient38_IRM_simu_mridian_gtv                         0.952777
# Patient38_mridian_ttt_2_gtv                            0.940297
# Patient38_mridian_ttt_4_gtv                            0.937656
# Patient38_mridian_ttt_5_gtv                            0.948086
# Patient10_IRM_simu_GIE_gtv                             0.980282
# ...                                                         ...
# Patient21_mridian_ttt_1_gtv                            0.949313
# Patient21_mridian_ttt_2_gtv                            0.947406
# Patient21_mridian_ttt_3_gtv                            0.944065
# Patient21_mridian_ttt_4_gtv                            0.946298
# Patient21_mridian_ttt_5_gtv                            0.943961
#
#                                 original_shape_VoxelVolume  \
# ID
# Patient38_IRM_simu_mridian_gtv                 24468.72055
# Patient38_mridian_ttt_2_gtv                    24538.01250
# Patient38_mridian_ttt_4_gtv                    24633.28894
# Patient38_mridian_ttt_5_gtv                    24633.28894
# Patient10_IRM_simu_GIE_gtv                     18968.67186
# ...                                                    ...
# Patient21_mridian_ttt_1_gtv                    46473.24606
# Patient21_mridian_ttt_2_gtv                    49574.06091
# Patient21_mridian_ttt_3_gtv                    50310.28790
# Patient21_mridian_ttt_4_gtv                    49179.96293
# Patient21_mridian_ttt_5_gtv                    47720.50119
#
#                                 original_glrlm_GrayLevelNonUniformity  \
# ID
# Patient38_IRM_simu_mridian_gtv                             190.926217
# Patient38_mridian_ttt_2_gtv                                217.844776
# Patient38_mridian_ttt_4_gtv                                200.358813
# Patient38_mridian_ttt_5_gtv                                179.600406
# Patient10_IRM_simu_GIE_gtv                                  45.638871
# ...                                                               ...
# Patient21_mridian_ttt_1_gtv                                343.800646
# Patient21_mridian_ttt_2_gtv                                327.195701
# Patient21_mridian_ttt_3_gtv                                371.783880
# Patient21_mridian_ttt_4_gtv                                358.299533
# Patient21_mridian_ttt_5_gtv                                369.064419
#
#                                 original_glcm_Imc1  \
# ID
# Patient38_IRM_simu_mridian_gtv           -0.111253
# Patient38_mridian_ttt_2_gtv              -0.122338
# Patient38_mridian_ttt_4_gtv              -0.146088
# Patient38_mridian_ttt_5_gtv              -0.135938
# Patient10_IRM_simu_GIE_gtv               -0.251375
# ...                                            ...
# Patient21_mridian_ttt_1_gtv              -0.115514
# Patient21_mridian_ttt_2_gtv              -0.131991
# Patient21_mridian_ttt_3_gtv              -0.126162
# Patient21_mridian_ttt_4_gtv              -0.122955
# Patient21_mridian_ttt_5_gtv              -0.126115
#
#                                 original_glcm_InverseVariance  ...  \
# ID                                                             ...
# Patient38_IRM_simu_mridian_gtv                       0.198082  ...
# Patient38_mridian_ttt_2_gtv                          0.232458  ...
# Patient38_mridian_ttt_4_gtv                          0.237727  ...
# Patient38_mridian_ttt_5_gtv                          0.210590  ...
# Patient10_IRM_simu_GIE_gtv                           0.095591  ...
# ...                                                       ...  ...
# Patient21_mridian_ttt_1_gtv                          0.202774  ...
# Patient21_mridian_ttt_2_gtv                          0.203683  ...
# Patient21_mridian_ttt_3_gtv                          0.217034  ...
# Patient21_mridian_ttt_4_gtv                          0.213320  ...
# Patient21_mridian_ttt_5_gtv                          0.222862  ...
#
#                                 original_glrlm_RunPercentage  \
# ID
# Patient38_IRM_simu_mridian_gtv                      0.936841
# Patient38_mridian_ttt_2_gtv                         0.920226
# Patient38_mridian_ttt_4_gtv                         0.916220
# Patient38_mridian_ttt_5_gtv                         0.930150
# Patient10_IRM_simu_GIE_gtv                          0.973497
# ...                                                      ...
# Patient21_mridian_ttt_1_gtv                         0.932217
# Patient21_mridian_ttt_2_gtv                         0.929239
# Patient21_mridian_ttt_3_gtv                         0.924673
# Patient21_mridian_ttt_4_gtv                         0.928144
# Patient21_mridian_ttt_5_gtv                         0.925087
#
#                                 original_glcm_Idm  original_shape_Sphericity  \
# ID
# Patient38_IRM_simu_mridian_gtv           0.194175                   0.607379
# Patient38_mridian_ttt_2_gtv              0.232382                   0.609360
# Patient38_mridian_ttt_4_gtv              0.239814                   0.610461
# Patient38_mridian_ttt_5_gtv              0.208133                   0.610461
# Patient10_IRM_simu_GIE_gtv               0.091445                   0.606230
# ...                                           ...                        ...
# Patient21_mridian_ttt_1_gtv              0.201275                   0.533882
# Patient21_mridian_ttt_2_gtv              0.202278                   0.636310
# Patient21_mridian_ttt_3_gtv              0.214623                   0.638639
# Patient21_mridian_ttt_4_gtv              0.211062                   0.534827
# Patient21_mridian_ttt_5_gtv              0.220140                   0.536294
#
#                                 original_glrlm_GrayLevelNonUniformityNormalized  \
# ID
# Patient38_IRM_simu_mridian_gtv                                         0.036070
# Patient38_mridian_ttt_2_gtv                                            0.041780
# Patient38_mridian_ttt_4_gtv                                            0.038445
# Patient38_mridian_ttt_5_gtv                                            0.033948
# Patient10_IRM_simu_GIE_gtv                                             0.010718
# ...                                                                         ...
# Patient21_mridian_ttt_1_gtv                                            0.034367
# Patient21_mridian_ttt_2_gtv                                            0.030759
# Patient21_mridian_ttt_3_gtv                                            0.034608
# Patient21_mridian_ttt_4_gtv                                            0.033993
# Patient21_mridian_ttt_5_gtv                                            0.036206
#
#                                 original_gldm_GrayLevelNonUniformity  \
# ID
# Patient38_IRM_simu_mridian_gtv                            205.558584
# Patient38_mridian_ttt_2_gtv                               239.276386
# Patient38_mridian_ttt_4_gtv                               219.398031
# Patient38_mridian_ttt_5_gtv                               193.812588
# Patient10_IRM_simu_GIE_gtv                                 47.090535
# ...                                                              ...
# Patient21_mridian_ttt_1_gtv                               372.545429
# Patient21_mridian_ttt_2_gtv                               357.278850
# Patient21_mridian_ttt_3_gtv                               409.237238
# Patient21_mridian_ttt_4_gtv                               391.036280
# Patient21_mridian_ttt_5_gtv                               403.227062
#
#                                 original_shape_Maximum2DDiameterSlice  \
# ID
# Patient38_IRM_simu_mridian_gtv                              47.606047
# Patient38_mridian_ttt_2_gtv                                 47.606047
# Patient38_mridian_ttt_4_gtv                                 47.606047
# Patient38_mridian_ttt_5_gtv                                 47.606047
# Patient10_IRM_simu_GIE_gtv                                  38.744658
# ...                                                               ...
# Patient21_mridian_ttt_1_gtv                                 70.373728
# Patient21_mridian_ttt_2_gtv                                 70.373728
# Patient21_mridian_ttt_3_gtv                                 70.373728
# Patient21_mridian_ttt_4_gtv                                 70.373728
# Patient21_mridian_ttt_5_gtv                                 70.373728
#
#                                 original_firstorder_Kurtosis  \
# ID
# Patient38_IRM_simu_mridian_gtv                      2.792427
# Patient38_mridian_ttt_2_gtv                         3.013965
# Patient38_mridian_ttt_4_gtv                         2.555804
# Patient38_mridian_ttt_5_gtv                         2.595478
# Patient10_IRM_simu_GIE_gtv                          2.281913
# ...                                                      ...
# Patient21_mridian_ttt_1_gtv                         2.937300
# Patient21_mridian_ttt_2_gtv                         3.333079
# Patient21_mridian_ttt_3_gtv                         3.497868
# Patient21_mridian_ttt_4_gtv                         2.693550
# Patient21_mridian_ttt_5_gtv                         2.736038
#
#                                 original_gldm_DependenceEntropy  \
# ID
# Patient38_IRM_simu_mridian_gtv                         7.284733
# Patient38_mridian_ttt_2_gtv                            7.324008
# Patient38_mridian_ttt_4_gtv                            7.459851
# Patient38_mridian_ttt_5_gtv                            7.451735
# Patient10_IRM_simu_GIE_gtv                             8.129849
# ...                                                         ...
# Patient21_mridian_ttt_1_gtv                            7.431735
# Patient21_mridian_ttt_2_gtv                            7.645271
# Patient21_mridian_ttt_3_gtv                            7.531429
# Patient21_mridian_ttt_4_gtv                            7.489155
# Patient21_mridian_ttt_5_gtv                            7.431000
#
#                                 original_glcm_JointEnergy  \
# ID
# Patient38_IRM_simu_mridian_gtv                   0.002152
# Patient38_mridian_ttt_2_gtv                      0.002954
# Patient38_mridian_ttt_4_gtv                      0.002655
# Patient38_mridian_ttt_5_gtv                      0.002042
# Patient10_IRM_simu_GIE_gtv                       0.000381
# ...                                                   ...
# Patient21_mridian_ttt_1_gtv                      0.002050
# Patient21_mridian_ttt_2_gtv                      0.001867
# Patient21_mridian_ttt_3_gtv                      0.002321
# Patient21_mridian_ttt_4_gtv                      0.002147
# Patient21_mridian_ttt_5_gtv                      0.002384
#
#                                 original_glszm_LargeAreaHighGrayLevelEmphasis
# ID
# Patient38_IRM_simu_mridian_gtv                                    5938.112207
# Patient38_mridian_ttt_2_gtv                                      12300.061020
# Patient38_mridian_ttt_4_gtv                                      11179.429970
# Patient38_mridian_ttt_5_gtv                                       6318.359375
# Patient10_IRM_simu_GIE_gtv                                       18557.740680
# ...                                                                       ...
# Patient21_mridian_ttt_1_gtv                                       9207.704603
# Patient21_mridian_ttt_2_gtv                                      11987.990760
# Patient21_mridian_ttt_3_gtv                                      13047.518340
# Patient21_mridian_ttt_4_gtv                                       9061.905427
# Patient21_mridian_ttt_5_gtv                                      10375.824380
#
# [485 rows x 49 columns]

# %% [markdown]
# ## Get patient list

# %%
patient_list = np.unique(repeatable_features_gtv_df['Patient Rxmic'].values)
print(patient_list.shape)
# Out:
# (83,)

# %% [markdown]
# 3 patients were ruled out

# %%
def extract_rad(extracted_feat_df, fraction: str, patient_list: list, features_list: list): 
    data = []
    error_patients = set()
    for patient in patient_list: 
        row_data = []
        try:
            line = extracted_feat_df.loc[(extracted_feat_df['Patient Rxmic'] == patient) & (extracted_feat_df['Fraction'] == fraction)].iloc[0]
            for feature in features_list:
                feature_value = line[feature]
                row_data.append(feature_value) # add the value to raw_data 
        except IndexError:
            for feature in features_list: 
                row_data.append(None)
            error_patients.add(patient)
            print("Error with patient ", patient)

        data.append(row_data)

    return data, error_patients

# %% [markdown]
# # Get features

# %% [markdown]
# ## Simu features

# %%
data_simu, error_patients = extract_rad(repeatable_features_gtv_df, fraction='Simulation mridian', patient_list=patient_list, features_list=filtered_features)
# Out:
# Error with patient  Patient 17
# Error with patient  Patient 18
# Error with patient  Patient 19
# Error with patient  Patient 21
# Error with patient  Patient 22
# Error with patient  Patient 23
# Error with patient  Patient 24
# Error with patient  Patient 32
# Error with patient  Patient 57
# Error with patient  Patient 66

# %% [markdown]
# Those are patients who did not have the MRIdian simulation. They got simulation at 1.5T instead.

# %%
simu_gtv_df = pd.DataFrame(data_simu, index=patient_list, columns=filtered_features)
simu_gtv_df.head()
# Out:
#             original_glcm_JointEntropy  original_glcm_Idn  original_glcm_Id  \
# Patient 1                     9.459772           0.925074          0.319977
# Patient 10                    9.121655           0.913871          0.316878
# Patient 11                    7.260484           0.946192          0.435826
# Patient 12                    8.203637           0.931228          0.379405
# Patient 13                    8.900018           0.926487          0.326043
#
#             original_shape_Maximum2DDiameterRow  original_glcm_MCC  \
# Patient 1                             69.193452           0.850239
# Patient 10                            56.582369           0.736920
# Patient 11                            69.995168           0.647232
# Patient 12                            53.962602           0.769851
# Patient 13                            60.133526           0.729234
#
#             original_glrlm_ShortRunEmphasis  original_shape_VoxelVolume  \
# Patient 1                          0.936791                 57035.93799
# Patient 10                         0.944792                 21173.02208
# Patient 11                         0.891533                 51224.07552
# Patient 12                         0.917521                 29791.20861
# Patient 13                         0.937422                 42164.15279
#
#             original_glrlm_GrayLevelNonUniformity  original_glcm_Imc1  \
# Patient 1                              412.358534           -0.161965
# Patient 10                             164.281722           -0.142684
# Patient 11                             829.237301           -0.109078
# Patient 12                             325.866594           -0.150878
# Patient 13                             375.681497           -0.121388
#
#             original_glcm_InverseVariance  ...  original_glrlm_RunPercentage  \
# Patient 1                        0.232486  ...                      0.914187
# Patient 10                       0.231669  ...                      0.925830
# Patient 11                       0.348995  ...                      0.853821
# Patient 12                       0.294375  ...                      0.890257
# Patient 13                       0.241209  ...                      0.916069
#
#             original_glcm_Idm  original_shape_Sphericity  \
# Patient 1            0.233873                   0.620984
# Patient 10           0.226624                   0.580770
# Patient 11           0.362001                   0.657315
# Patient 12           0.295542                   0.728817
# Patient 13           0.237198                   0.700884
#
#             original_glrlm_GrayLevelNonUniformityNormalized  \
# Patient 1                                          0.034244
# Patient 10                                         0.036296
# Patient 11                                         0.082086
# Patient 12                                         0.053204
# Patient 13                                         0.042118
#
#             original_gldm_GrayLevelNonUniformity  \
# Patient 1                             465.737737
# Patient 10                            177.880753
# Patient 11                           1027.238079
# Patient 12                            379.236953
# Patient 13                            419.164955
#
#             original_shape_Maximum2DDiameterSlice  \
# Patient 1                               67.797028
# Patient 10                              36.629694
# Patient 11                              49.332752
# Patient 12                              39.693094
# Patient 13                              49.494058
#
#             original_firstorder_Kurtosis  original_gldm_DependenceEntropy  \
# Patient 1                       2.867730                         7.777353
# Patient 10                      2.489548                         7.393406
# Patient 11                      7.305087                         7.068595
# Patient 12                      4.218738                         7.289950
# Patient 13                      3.847257                         7.376553
#
#             original_glcm_JointEnergy  \
# Patient 1                    0.002607
# Patient 10                   0.002365
# Patient 11                   0.011753
# Patient 12                   0.005702
# Patient 13                   0.003239
#
#             original_glszm_LargeAreaHighGrayLevelEmphasis
# Patient 1                                     30809.85499
# Patient 10                                     8648.95427
# Patient 11                                   547640.95430
# Patient 12                                    52709.72484
# Patient 13                                    18177.12628
#
# [5 rows x 49 columns]

# %%
simu_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/simu_mridian_gtv.csv')

# %% [markdown]
# ## F1 features

# %%
data_f1, error_patients = extract_rad(repeatable_features_gtv_df, fraction='1', patient_list=patient_list, features_list=filtered_features)
# Out:
# Error with patient  Patient 38
# Error with patient  Patient 80

# %%
f1_gtv_df = pd.DataFrame(data_f1, index=patient_list, columns=filtered_features)
f1_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/f1_gtv.csv')

# %% [markdown]
# ## F2 features

# %%
data_f2, error_patients = extract_rad(repeatable_features_gtv_df, fraction='2', patient_list=patient_list, features_list=filtered_features)
# Out:
# Error with patient  Patient 62
# Error with patient  Patient 74
# Error with patient  Patient 80
# Error with patient  Patient 82
# Error with patient  Patient 84
# Error with patient  Patient 85

# %%
f2_gtv_df = pd.DataFrame(data_f2, index=patient_list, columns=filtered_features)
f2_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/f2_gtv.csv')

# %% [markdown]
# ## F3 features

# %%
data_f3, error_patients = extract_rad(repeatable_features_gtv_df, fraction='3', patient_list=patient_list, features_list=filtered_features)
# Out:
# Error with patient  Patient 38
# Error with patient  Patient 56
# Error with patient  Patient 63
# Error with patient  Patient 74

# %%
f3_gtv_df = pd.DataFrame(data_f3, index=patient_list, columns=filtered_features)
f3_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/f3_gtv.csv')

# %% [markdown]
# ## F4 features

# %%
data_f4, error_patients = extract_rad(repeatable_features_gtv_df, fraction='4', patient_list=patient_list, features_list=filtered_features)
# Out:
# Error with patient  Patient 70
# Error with patient  Patient 74
# Error with patient  Patient 80
# Error with patient  Patient 81

# %%
f4_gtv_df = pd.DataFrame(data_f4, index=patient_list, columns=filtered_features)
f4_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/f4_gtv.csv')

# %% [markdown]
# ## F5 features

# %%
data_f5, error_patients = extract_rad(repeatable_features_gtv_df, fraction='5', patient_list=patient_list, features_list=filtered_features)
# Out:
# Error with patient  Patient 54
# Error with patient  Patient 61
# Error with patient  Patient 64
# Error with patient  Patient 66
# Error with patient  Patient 71
# Error with patient  Patient 79
# Error with patient  Patient 86

# %%
f5_gtv_df = pd.DataFrame(data_f5, index=patient_list, columns=filtered_features)
f5_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/f5_gtv.csv')

# %% [markdown]
# # Get delta-rad features

# %%
def extract_delta_rad(extracted_feat_df, fraction1: str, fraction2: str, patient_list: list, features_list: list): 
    '''Compute the delta radiomics features by computing ratio between two fractions. '''

    data = []
    error_patients = set()
    for patient in patient_list: 
        row_data = []
        try:
            line1 = extracted_feat_df.loc[(extracted_feat_df['Patient Rxmic'] == patient) & (extracted_feat_df['Fraction'] == fraction1)].iloc[0]
            line2 = extracted_feat_df.loc[(extracted_feat_df['Patient Rxmic'] == patient) & (extracted_feat_df['Fraction'] == fraction2)].iloc[0]
            for feature in features_list:
                feature_value1 = line1[feature]
                feature_value2 = line2[feature]
                delta_feature = feature_value2 / feature_value1 
                row_data.append(delta_feature) # add the value to raw_data 
        except IndexError:
            for feature in features_list: 
                row_data.append(None)
            error_patients.add(patient)
            print("Error with patient ", patient)

        data.append(row_data)

    return data, error_patients

def extract_delta_rad2(extracted_feat_df, fraction1: str, fraction2: str, patient_list: list, features_list: list): 
    '''Compute the delta radiomics features by computing the relative difference between two fractions. '''
    data = []
    error_patients = set()
    for patient in patient_list: 
        row_data = []
        try:
            line1 = extracted_feat_df.loc[(extracted_feat_df['Patient Rxmic'] == patient) & (extracted_feat_df['Fraction'] == fraction1)].iloc[0]
            line2 = extracted_feat_df.loc[(extracted_feat_df['Patient Rxmic'] == patient) & (extracted_feat_df['Fraction'] == fraction2)].iloc[0]
            for feature in features_list:
                feature_value1 = line1[feature]
                feature_value2 = line2[feature]
                delta_feature = (feature_value2 - feature_value1) / feature_value1
                row_data.append(delta_feature) # add the value to raw_data 
        except IndexError:
            for feature in features_list: 
                row_data.append(None)
            error_patients.add(patient)
            print("Error with patient ", patient)

        data.append(row_data)

    return data, error_patients

# %% [markdown]
# ## Simu/F1

# %%
# relative difference technique
data_simu_f1, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='Simulation mridian', fraction2='1', patient_list=patient_list, features_list=filtered_features)
simu_f1_gtv_df = pd.DataFrame(data_simu_f1, index=patient_list, columns=filtered_features)
simu_f1_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_simu_f1_gtv.csv')
# Out:
# Error with patient  Patient 17
# Error with patient  Patient 18
# Error with patient  Patient 19
# Error with patient  Patient 21
# Error with patient  Patient 22
# Error with patient  Patient 23
# Error with patient  Patient 24
# Error with patient  Patient 32
# Error with patient  Patient 38
# Error with patient  Patient 57
# Error with patient  Patient 66
# Error with patient  Patient 80

# %% [markdown]
# ## Simu/F3

# %%
data_simu_f3, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='Simulation mridian', fraction2='3', patient_list=patient_list, features_list=filtered_features)
simu_f3_gtv_df = pd.DataFrame(data_simu_f3, index=patient_list, columns=filtered_features)
simu_f3_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_simu_f3_gtv.csv')
# Out:
# Error with patient  Patient 17
# Error with patient  Patient 18
# Error with patient  Patient 19
# Error with patient  Patient 21
# Error with patient  Patient 22
# Error with patient  Patient 23
# Error with patient  Patient 24
# Error with patient  Patient 32
# Error with patient  Patient 38
# Error with patient  Patient 56
# Error with patient  Patient 57
# Error with patient  Patient 63
# Error with patient  Patient 66
# Error with patient  Patient 74

# %% [markdown]
# ## Simu/F5

# %%
data_simu_f5, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='Simulation mridian', fraction2='5', patient_list=patient_list, features_list=filtered_features)
simu_f5_gtv_df = pd.DataFrame(data_simu_f5, index=patient_list, columns=filtered_features)
simu_f5_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_simu_f5_gtv.csv')
# Out:
# Error with patient  Patient 17
# Error with patient  Patient 18
# Error with patient  Patient 19
# Error with patient  Patient 21
# Error with patient  Patient 22
# Error with patient  Patient 23
# Error with patient  Patient 24
# Error with patient  Patient 32
# Error with patient  Patient 54
# Error with patient  Patient 57
# Error with patient  Patient 61
# Error with patient  Patient 64
# Error with patient  Patient 66
# Error with patient  Patient 71
# Error with patient  Patient 79
# Error with patient  Patient 86

# %% [markdown]
# ## F1/F2

# %%
# relative difference technique
data_f1_f2, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='1', fraction2='2', patient_list=patient_list, features_list=filtered_features)
f1_f2_gtv_df = pd.DataFrame(data_f1_f2, index=patient_list, columns=filtered_features)
f1_f2_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_f1_f2_gtv.csv')
# Out:
# Error with patient  Patient 38
# Error with patient  Patient 62
# Error with patient  Patient 74
# Error with patient  Patient 80
# Error with patient  Patient 82
# Error with patient  Patient 84
# Error with patient  Patient 85

# %% [markdown]
# ## F2/F3

# %%
# relative difference technique
data_f2_f3, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='2', fraction2='3', patient_list=patient_list, features_list=filtered_features)
f2_f3_gtv_df = pd.DataFrame(data_f2_f3, index=patient_list, columns=filtered_features)
f2_f3_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_f2_f3_gtv.csv')
# Out:
# Error with patient  Patient 38
# Error with patient  Patient 56
# Error with patient  Patient 62
# Error with patient  Patient 63
# Error with patient  Patient 74
# Error with patient  Patient 80
# Error with patient  Patient 82
# Error with patient  Patient 84
# Error with patient  Patient 85

# %% [markdown]
# ## F1/F3

# %%
# relative differnce technique
data_f1_f3, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='1', fraction2='3', patient_list=patient_list, features_list=filtered_features)
f1_f3_gtv_df = pd.DataFrame(data_f1_f3, index=patient_list, columns=filtered_features)
f1_f3_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_f1_f3_gtv.csv')
# Out:
# Error with patient  Patient 38
# Error with patient  Patient 56
# Error with patient  Patient 63
# Error with patient  Patient 74
# Error with patient  Patient 80

# %% [markdown]
# ## F1/F4

# %%
# relative difference technique
data_f1_f4, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='1', fraction2='4', patient_list=patient_list, features_list=filtered_features)
f1_f4_gtv_df = pd.DataFrame(data_f1_f4, index=patient_list, columns=filtered_features)
f1_f4_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_f1_f4_gtv.csv')
# Out:
# Error with patient  Patient 38
# Error with patient  Patient 70
# Error with patient  Patient 74
# Error with patient  Patient 80
# Error with patient  Patient 81

# %% [markdown]
# ## F1/F5

# %%
# relative difference technique
data_f1_f5, error_patients = extract_delta_rad2(repeatable_features_gtv_df, fraction1='1', fraction2='5', patient_list=patient_list, features_list=filtered_features)
f1_f5_gtv_df = pd.DataFrame(data_f1_f5, index=patient_list, columns=filtered_features)
f1_f5_gtv_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/rd_f1_f5_gtv.csv')
# Out:
# Error with patient  Patient 38
# Error with patient  Patient 54
# Error with patient  Patient 61
# Error with patient  Patient 64
# Error with patient  Patient 66
# Error with patient  Patient 71
# Error with patient  Patient 79
# Error with patient  Patient 80
# Error with patient  Patient 86

# %% [markdown]
# # Get patient outcomes

# %%
outcome_features = list(repeatable_features_gtv_df.columns)[-5:]
outcome_features
# Out:
# ['Récidive Locale', 'Récidive Méta', 'Décès', 'Récidive', 'Évènement']

# %%
def extract_outcomes(extracted_feat_df, patient_list: list, features_list: list): 
    data = []
    error_patients = set()
    for patient in patient_list: 
        row_data = []
        try:
            line = extracted_feat_df.loc[(extracted_feat_df['Patient Rxmic'] == patient)].iloc[0]
            for feature in features_list:
                outcome_value = line[feature]
                row_data.append(outcome_value) # add the value to raw_data 
        except IndexError:
            for feature in features_list: 
                row_data.append(None)
            error_patients.add(patient)
            print("Error with patient ", patient)

        data.append(row_data)

    return data, error_patients

# %%
outcome_data, error_patients = extract_outcomes(repeatable_features_gtv_df, patient_list, outcome_features)

# %%
outcome_df = pd.DataFrame(outcome_data, index=patient_list, columns=outcome_features)
outcome_df.to_csv('/home/tachennf/Documents/delta-rad/data/ICM_0.35T/extracted_radiomics/outcomes.csv')

# %%
outcome_df
# Out:
#             Récidive Locale  Récidive Méta  Décès  Récidive  Évènement
# Patient 1                 0              1      1         1          1
# Patient 10                0              1      1         1          1
# Patient 11                0              1      1         1          1
# Patient 12                0              0      0         0          0
# Patient 13                0              1      0         1          1
# ...                     ...            ...    ...       ...        ...
# Patient 83                0              0      0         0          0
# Patient 84                0              1      0         1          1
# Patient 85                0              0      0         0          0
# Patient 86                0              0      1         0          1
# Patient 9                 1              1      1         1          1
#
# [83 rows x 5 columns]

# %% [markdown]
# ## Outcomes statistics

# %%
outcome_df["Récidive Locale"].value_counts()
# Out:
# Récidive Locale
# 0    63
# 1    20
# Name: count, dtype: int64

# %%
outcome_df["Récidive Méta"].value_counts()
# Out:
# Récidive Méta
# 1    62
# 0    21
# Name: count, dtype: int64

# %%
outcome_df["Décès"].value_counts()
# Out:
# Décès
# 0    48
# 1    35
# Name: count, dtype: int64
